# %%
import pandas as pd
import requests as rq
from dotenv import load_dotenv
import base64
import os
import urllib
import json
load_dotenv()
from src import API as api

# %%
country = 'es' #values: es, it, pt
locale = 'es' #values: es, it, pt, en, ca
language = 'es' #
max_items = '50'
operation = 'rent' 
property_type = 'homes'
order = 'priceDown' 
center = '40.24594,-3.42922' 
distance = '60000'
sort = 'desc'

df_tot = pd.DataFrame()
limit = 20

for i in range(1,limit):
    url = ('https://api.idealista.com/3.5/'+country+'/search?operation='+operation+#"&locale="+locale+
           '&maxItems='+max_items+
           '&order='+order+
           '&center='+center+
           '&distance='+distance+
           '&propertyType='+property_type+
           '&sort='+sort+ 
           '&numPage=%s'+
           '&language='+language) %(i)  
    a = api.search_api(api.get_oauth_token(), url)
    df = pd.DataFrame.from_dict(a['elementList'])
    df_tot = pd.concat([df_tot,df])

df_tot = df_tot.reset_index()

# %%
df_tot
# Out:
#      index                           address  bathrooms country  \
# 0        0                      Calle bailén          2      es
# 1        1                 Calle los rosales          3      es
# 2        2                   Callejón PARAJE          1      es
# 3        3                    Cuesta de prim          1      es
# 4        4                       Palmaces, 2          1      es
# ..     ...                               ...        ...     ...
# 445     45                        Calle Real          1      es
# 446     46         Calle Buitrago del Lozoya          1      es
# 447     47  Calle de Ramón Gómez de la Serna          2      es
# 448     48                  Paseo del Ferrol          2      es
# 449     49      Calle de Martínez de la Riva          1      es
#
#                                           detailedType distance  \
# 0    {'typology': 'chalet', 'subTypology': 'indepen...    45671
# 1    {'typology': 'chalet', 'subTypology': 'terrace...    46436
# 2    {'typology': 'chalet', 'subTypology': 'indepen...    36362
# 3    {'typology': 'chalet', 'subTypology': 'terrace...    46362
# 4                                 {'typology': 'flat'}    41037
# ..                                                 ...      ...
# 445                               {'typology': 'flat'}    20178
# 446                               {'typology': 'flat'}     6061
# 447                               {'typology': 'flat'}     7513
# 448                               {'typology': 'flat'}    17324
# 449                               {'typology': 'flat'}     4375
#
#                 district  exterior  externalReference floor  ...  \
# 0                    NaN     False        203-5955138   NaN  ...
# 1                    NaN     False        203-6876767    bj  ...
# 2                    NaN     False     R-887666456-PT   NaN  ...
# 3                    NaN     False        203-6874807   NaN  ...
# 4             El Vallejo      True  PLAMACES AZUQUECA     3  ...
# ..                   ...       ...                ...   ...  ...
# 445  Villayuventus-Renfe      True          3285PV-AZ     4  ...
# 446           Fuencarral      True          PRPEGASUS     1  ...
# 447           Fuencarral      True          9095AL-AM    bj  ...
# 448          Los Arroyos      True         9174AL-AMV     1  ...
# 449   Puente de Vallecas      True                NaN     1  ...
#
#      propertyCode  propertyType     province  rooms  showAddress   size  \
# 0        38626728        chalet       Madrid      3        False  155.0
# 1        40107715        chalet       Toledo      4        False  196.0
# 2        87955479        chalet       Madrid      3        False   70.0
# 3        40107545        chalet       Toledo      1        False  114.0
# 4        84910102          flat  Guadalajara      2         True   83.0
# ..            ...           ...          ...    ...          ...    ...
# 445      86198791          flat       Madrid      3        False   75.0
# 446      87286962          flat       Madrid      1        False   63.0
# 447      86602202          flat       Madrid      4        False  130.0
# 448      87064321          flat       Madrid      2        False  143.0
# 449      87727677          flat       Madrid      2        False   70.0
#
#      status                                     suggestedTexts  \
# 0      good  {'subtitle': 'Villarejo de Salvanés', 'title':...
# 1      good  {'subtitle': 'Méntrida', 'title': 'Chalet ados...
# 2      good  {'subtitle': 'Perales de Tajuña', 'title': 'Ca...
# 3      good  {'subtitle': 'Méntrida', 'title': 'Chalet ados...
# 4      good  {'subtitle': 'El Vallejo, Azuqueca de Henares'...
# ..      ...                                                ...
# 445    good  {'subtitle': 'Villayuventus-Renfe, Parla', 'ti...
# 446    good  {'subtitle': 'Peñagrande, Madrid', 'title': 'P...
# 447    good  {'subtitle': 'Peñagrande, Madrid', 'title': 'P...
# 448    good  {'subtitle': 'Los Arroyos, San Sebastián de lo...
# 449    good  {'subtitle': 'San Diego, Madrid', 'title': 'Pi...
#
#                                              thumbnail  \
# 0    https://img3.idealista.com/blur/WEB_LISTING/0/...
# 1    https://img3.idealista.com/blur/WEB_LISTING/0/...
# 2    https://img3.idealista.com/blur/WEB_LISTING/0/...
# 3    https://img3.idealista.com/blur/WEB_LISTING/0/...
# 4    https://img3.idealista.com/blur/WEB_LISTING/0/...
# ..                                                 ...
# 445  https://img3.idealista.com/blur/WEB_LISTING/0/...
# 446  https://img3.idealista.com/blur/WEB_LISTING/0/...
# 447  https://img3.idealista.com/blur/WEB_LISTING/0/...
# 448  https://img3.idealista.com/blur/WEB_LISTING/0/...
# 449  https://img3.idealista.com/blur/WEB_LISTING/0/...
#
#                                               url
# 0    https://www.idealista.com/inmueble/38626728/
# 1    https://www.idealista.com/inmueble/40107715/
# 2    https://www.idealista.com/inmueble/87955479/
# 3    https://www.idealista.com/inmueble/40107545/
# 4    https://www.idealista.com/inmueble/84910102/
# ..                                            ...
# 445  https://www.idealista.com/inmueble/86198791/
# 446  https://www.idealista.com/inmueble/87286962/
# 447  https://www.idealista.com/inmueble/86602202/
# 448  https://www.idealista.com/inmueble/87064321/
# 449  https://www.idealista.com/inmueble/87727677/
#
# [450 rows x 36 columns]

# %%
df_tot.columns
# Out:
# Index(['index', 'address', 'bathrooms', 'country', 'detailedType', 'distance',
#        'district', 'exterior', 'externalReference', 'floor', 'has360',
#        'has3DTour', 'hasLift', 'hasPlan', 'hasVideo', 'latitude', 'longitude',
#        'municipality', 'neighborhood', 'newDevelopment',
#        'newDevelopmentFinished', 'numPhotos', 'operation', 'parkingSpace',
#        'price', 'priceByArea', 'propertyCode', 'propertyType', 'province',
#        'rooms', 'showAddress', 'size', 'status', 'suggestedTexts', 'thumbnail',
#        'url'],
#       dtype='object')
