# %%
import pandas as pd
import requests as rq
from dotenv import load_dotenv
import base64
import os
import urllib
import json
from src import API as api
load_dotenv()
# Out:
# True

# %%
country = 'es' #values: es, it, pt
locale = 'es' #values: es, it, pt, en, ca
language = 'es' #
max_items = '50'
operation = 'rent' 
property_type = 'homes'
order = 'priceDown' 
center = '40.24594,-3.42922' 
distance = '60000'
sort = 'desc'

df_tot = pd.DataFrame()
limit = 200

for i in range(1,limit):
    url = ('https://api.idealista.com/3.5/'+country+'/search?operation='+operation+#"&locale="+locale+
           '&maxItems='+max_items+
           '&order='+order+
           '&center='+center+
           '&distance='+distance+
           '&propertyType='+property_type+
           '&sort='+sort+ 
           '&numPage=%s'+
           '&language='+language) %(i)  
    a = api.search_api(api.get_oauth_token(), url)
    df = pd.DataFrame.from_dict(a['elementList'])
    df_tot = pd.concat([df_tot,df])

df_tot = df_tot.reset_index()
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-10-bfd9b93247be> in <module>
#      23            '&numPage=%s'+
#      24            '&language='+language) %(i)
# ---> 25     a = api.search_api(api.get_oauth_token(), url)
#      26     df = pd.DataFrame.from_dict(a['elementList'])
#      27     df_tot = pd.concat([df_tot,df])
#
# ~/ironhack/proyecto-final/SearchBestRent/src/API.py in search_api(token, url)
#      24     headers = {'Content-Type': 'Content-Type: multipart/form-data;', 'Authorization' : 'Bearer ' + token}
#      25     content = rq.post(url, headers = headers)
# ---> 26     result = json.loads(content.text)
#      27     return result
#
# /usr/lib/python3.7/json/__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     346             parse_int is None and parse_float is None and
#     347             parse_constant is None and object_pairs_hook is None and not kw):
# --> 348         return _default_decoder.decode(s)
#     349     if cls is None:
#     350         cls = JSONDecoder
#
# /usr/lib/python3.7/json/decoder.py in decode(self, s, _w)
#     335
#     336         """
# --> 337         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338         end = _w(s, end).end()
#     339         if end != len(s):
#
# /usr/lib/python3.7/json/decoder.py in raw_decode(self, s, idx)
#     353             obj, end = self.scan_once(s, idx)
#     354         except StopIteration as err:
# --> 355             raise JSONDecodeError("Expecting value", s, err.value) from None
#     356         return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %%
df_tot2 = df_tot.copy()

# %%
df_tot2
# Out:
#                            address  bathrooms country  \
# 0    Calle de Carretas, Madrid, 25          1      es
# 1    Calle de Carretas, Madrid, 25          1      es
# 2    Calle de Carretas, Madrid, 25          1      es
# 3                  Calle Estocolmo          1      es
# 4                    Calle Iriarte          1      es
# ..                             ...        ...     ...
# 45        Calle Francisco Guerrero          4      es
# 46    barrio Marazuela- El Torreón          1      es
# 47                Calle de Viriato          1      es
# 48  Calle del Puerto de Maspalomas          1      es
# 49                 Calle Garellano          1      es
#
#                                          detailedType distance  \
# 0       {'typology': 'flat', 'subTypology': 'studio'}    29898
# 1    {'typology': 'flat', 'subTypology': 'penthouse'}    29898
# 2       {'typology': 'flat', 'subTypology': 'studio'}    29898
# 3                                {'typology': 'flat'}    36254
# 4                                {'typology': 'flat'}    29597
# ..                                                ...      ...
# 45  {'typology': 'chalet', 'subTypology': 'semidet...    42509
# 46                               {'typology': 'flat'}    47298
# 47                               {'typology': 'flat'}    31091
# 48                               {'typology': 'flat'}    35269
# 49                               {'typology': 'flat'}    32548
#
#                           district  exterior     externalReference floor  \
# 0                           Centro     False       Carretas Bajo B    bj
# 1                           Centro     False      Sol 3C Int Attic     3
# 2                           Centro      True   Sol 4A Stu Int Atic     4
# 3   Parque oeste - Fuente Cisneros      True                   NaN     3
# 4                        Salamanca     False  ca31875ef7d0d581c9eb     1
# ..                             ...       ...                   ...   ...
# 45                             NaN     False                   NaN   NaN
# 46           Marazuela- El Torreón      True                   NaN    bj
# 47                        Chamberí      True                 10166     2
# 48                      Fuencarral      True                   NaN     1
# 49                          Tetuán     False                 09714     3
#
#     has360  ...  propertyCode propertyType  province  rooms  showAddress  \
# 0    False  ...      84227990       studio    Madrid      0         True
# 1    False  ...      84590828    penthouse    Madrid      1         True
# 2    False  ...      84203646       studio    Madrid      0         True
# 3    False  ...      86731685         flat    Madrid      2        False
# 4    False  ...      87191834         flat    Madrid      1        False
# ..     ...  ...           ...          ...       ...    ...          ...
# 45   False  ...      88058597       chalet    Madrid      4        False
# 46   False  ...      88058576         flat    Madrid      2        False
# 47   False  ...      88058550         flat    Madrid      1        False
# 48   False  ...      88058531         flat    Madrid      2        False
# 49   False  ...      88058508         flat    Madrid      1        False
#
#      size status                                     suggestedTexts  \
# 0    45.0   good  {'subtitle': 'Sol, Madrid', 'title': 'Estudio ...
# 1    30.0   good  {'subtitle': 'Sol, Madrid', 'title': 'Ático en...
# 2    30.0   good  {'subtitle': 'Sol, Madrid', 'title': 'Estudio ...
# 3    62.0   good  {'subtitle': 'Parque oeste - Fuente Cisneros, ...
# 4    70.0    NaN  {'subtitle': 'Guindalera, Madrid', 'title': 'P...
# ..    ...    ...                                                ...
# 45  220.0   good  {'subtitle': 'Club de Campo', 'title': 'Chalet...
# 46  130.0   good  {'subtitle': 'Marazuela- El Torreón, Las Rozas...
# 47   75.0   good  {'subtitle': 'Trafalgar, Madrid', 'title': 'Pi...
# 48   78.0   good  {'subtitle': 'Pilar, Madrid', 'title': 'Piso e...
# 49   55.0   good  {'subtitle': 'Bellas Vistas, Madrid', 'title':...
#
#                                             thumbnail  \
# 0   https://img3.idealista.com/blur/WEB_LISTING/0/...
# 1   https://img3.idealista.com/blur/WEB_LISTING/0/...
# 2   https://img3.idealista.com/blur/WEB_LISTING/0/...
# 3   https://img3.idealista.com/blur/WEB_LISTING/0/...
# 4   https://img3.idealista.com/blur/WEB_LISTING/0/...
# ..                                                ...
# 45  https://img3.idealista.com/blur/WEB_LISTING/0/...
# 46  https://img3.idealista.com/blur/WEB_LISTING/0/...
# 47  https://img3.idealista.com/blur/WEB_LISTING/0/...
# 48  https://img3.idealista.com/blur/WEB_LISTING/0/...
# 49  https://img3.idealista.com/blur/WEB_LISTING/0/...
#
#                                              url
# 0   https://www.idealista.com/inmueble/84227990/
# 1   https://www.idealista.com/inmueble/84590828/
# 2   https://www.idealista.com/inmueble/84203646/
# 3   https://www.idealista.com/inmueble/86731685/
# 4   https://www.idealista.com/inmueble/87191834/
# ..                                           ...
# 45  https://www.idealista.com/inmueble/88058597/
# 46  https://www.idealista.com/inmueble/88058576/
# 47  https://www.idealista.com/inmueble/88058550/
# 48  https://www.idealista.com/inmueble/88058531/
# 49  https://www.idealista.com/inmueble/88058508/
#
# [1600 rows x 34 columns]

# %%
df_tot
# Out:
#                            address  bathrooms country  \
# 0    Calle de Carretas, Madrid, 25          1      es
# 1    Calle de Carretas, Madrid, 25          1      es
# 2    Calle de Carretas, Madrid, 25          1      es
# 3                  Calle Estocolmo          1      es
# 4                    Calle Iriarte          1      es
# ..                             ...        ...     ...
# 45        Calle Francisco Guerrero          4      es
# 46    barrio Marazuela- El Torreón          1      es
# 47                Calle de Viriato          1      es
# 48  Calle del Puerto de Maspalomas          1      es
# 49                 Calle Garellano          1      es
#
#                                          detailedType distance  \
# 0       {'typology': 'flat', 'subTypology': 'studio'}    29898
# 1    {'typology': 'flat', 'subTypology': 'penthouse'}    29898
# 2       {'typology': 'flat', 'subTypology': 'studio'}    29898
# 3                                {'typology': 'flat'}    36254
# 4                                {'typology': 'flat'}    29597
# ..                                                ...      ...
# 45  {'typology': 'chalet', 'subTypology': 'semidet...    42509
# 46                               {'typology': 'flat'}    47298
# 47                               {'typology': 'flat'}    31091
# 48                               {'typology': 'flat'}    35269
# 49                               {'typology': 'flat'}    32548
#
#                           district  exterior     externalReference floor  \
# 0                           Centro     False       Carretas Bajo B    bj
# 1                           Centro     False      Sol 3C Int Attic     3
# 2                           Centro      True   Sol 4A Stu Int Atic     4
# 3   Parque oeste - Fuente Cisneros      True                   NaN     3
# 4                        Salamanca     False  ca31875ef7d0d581c9eb     1
# ..                             ...       ...                   ...   ...
# 45                             NaN     False                   NaN   NaN
# 46           Marazuela- El Torreón      True                   NaN    bj
# 47                        Chamberí      True                 10166     2
# 48                      Fuencarral      True                   NaN     1
# 49                          Tetuán     False                 09714     3
#
#     has360  ...  propertyCode propertyType  province  rooms  showAddress  \
# 0    False  ...      84227990       studio    Madrid      0         True
# 1    False  ...      84590828    penthouse    Madrid      1         True
# 2    False  ...      84203646       studio    Madrid      0         True
# 3    False  ...      86731685         flat    Madrid      2        False
# 4    False  ...      87191834         flat    Madrid      1        False
# ..     ...  ...           ...          ...       ...    ...          ...
# 45   False  ...      88058597       chalet    Madrid      4        False
# 46   False  ...      88058576         flat    Madrid      2        False
# 47   False  ...      88058550         flat    Madrid      1        False
# 48   False  ...      88058531         flat    Madrid      2        False
# 49   False  ...      88058508         flat    Madrid      1        False
#
#      size status                                     suggestedTexts  \
# 0    45.0   good  {'subtitle': 'Sol, Madrid', 'title': 'Estudio ...
# 1    30.0   good  {'subtitle': 'Sol, Madrid', 'title': 'Ático en...
# 2    30.0   good  {'subtitle': 'Sol, Madrid', 'title': 'Estudio ...
# 3    62.0   good  {'subtitle': 'Parque oeste - Fuente Cisneros, ...
# 4    70.0    NaN  {'subtitle': 'Guindalera, Madrid', 'title': 'P...
# ..    ...    ...                                                ...
# 45  220.0   good  {'subtitle': 'Club de Campo', 'title': 'Chalet...
# 46  130.0   good  {'subtitle': 'Marazuela- El Torreón, Las Rozas...
# 47   75.0   good  {'subtitle': 'Trafalgar, Madrid', 'title': 'Pi...
# 48   78.0   good  {'subtitle': 'Pilar, Madrid', 'title': 'Piso e...
# 49   55.0   good  {'subtitle': 'Bellas Vistas, Madrid', 'title':...
#
#                                             thumbnail  \
# 0   https://img3.idealista.com/blur/WEB_LISTING/0/...
# 1   https://img3.idealista.com/blur/WEB_LISTING/0/...
# 2   https://img3.idealista.com/blur/WEB_LISTING/0/...
# 3   https://img3.idealista.com/blur/WEB_LISTING/0/...
# 4   https://img3.idealista.com/blur/WEB_LISTING/0/...
# ..                                                ...
# 45  https://img3.idealista.com/blur/WEB_LISTING/0/...
# 46  https://img3.idealista.com/blur/WEB_LISTING/0/...
# 47  https://img3.idealista.com/blur/WEB_LISTING/0/...
# 48  https://img3.idealista.com/blur/WEB_LISTING/0/...
# 49  https://img3.idealista.com/blur/WEB_LISTING/0/...
#
#                                              url
# 0   https://www.idealista.com/inmueble/84227990/
# 1   https://www.idealista.com/inmueble/84590828/
# 2   https://www.idealista.com/inmueble/84203646/
# 3   https://www.idealista.com/inmueble/86731685/
# 4   https://www.idealista.com/inmueble/87191834/
# ..                                           ...
# 45  https://www.idealista.com/inmueble/88058597/
# 46  https://www.idealista.com/inmueble/88058576/
# 47  https://www.idealista.com/inmueble/88058550/
# 48  https://www.idealista.com/inmueble/88058531/
# 49  https://www.idealista.com/inmueble/88058508/
#
# [1600 rows x 34 columns]
