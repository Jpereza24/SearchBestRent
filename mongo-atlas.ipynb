# %%
from pymongo import MongoClient
import getpass
import json
import os
from src import connectCollection as cc
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
connection = os.getenv("MONGOURL")

# %%
client = MongoClient(connection)

# %%
def connectCollection(database, collection):
    db = client[database]
    coll = db[collection]
    return db, coll

# %%
db, col = connectCollection("Pisos", "pisos")

# %%
query = list(col.find())

# %%
with open('pisos.json') as f:
    pisos_json = json.load(f)
col.insert_many(pisos_json)

# %%
# Out:
# [{'Street': 'Chalet en Hispanoamerica',
#   'District': 'Chamartín',
#   'Property_Type': 'Chalet',
#   'Price': 3250,
#   'm2': 211,
#   'Rooms': 4,
#   'location': {'type': 'Point', 'coordinates': [-3.4036, 40.272]},
#   '_id': ObjectId('5df7bac0ce267b38a9ae4b51')},
#  {'Street': 'Piso en Hispanoamerica',
#   'District': 'Chamartín',
#   'Property_Type': 'Piso',
#   'Price': 1350,
#   'm2': 92,
#   'Rooms': 3,
#   'location': {'type': 'Point', 'coordinates': [-3.6797153, 40.4552066]},
#   '_id': ObjectId('5df7bac0ce267b38a9ae4b52')},
#  {'Street': 'Piso en Universidad',
#   'District': 'Centro',
#   'Property_Type': 'Piso',
#   'Price': 1300,
#   'm2': 75,
#   'Rooms': 1,
#   'location': {'type': 'Point', 'coordinates': [-3.706918, 40.424238]},
#   '_id': ObjectId('5df7bac0ce267b38a9ae4b53')},
#  {'Street': 'Piso en Goya',
#   'District': 'Salamanca',
#   'Property_Type': 'Piso',
#   'Price': 1400,
#   'm2': 90,
#   'Rooms': 2,
#   'location': {'type': 'Point', 'coordinates': [-3.6807456, 40.4248439]},
#   '_id': ObjectId('5df7bac0ce267b38a9ae4b54')},
#  {'Street': 'Dúplex en Universidad',
#   'District': 'Centro',
#   'Property_Type': 'Dúplex',
#   'Price': 850,
#   'm2': 45,
#   'Rooms': 1,
#   'location': {'type': 'Point', 'coordinates': [-3.6930632, 40.4219589]},
#   '_id': ObjectId('5df7bac0ce267b38a9ae4b55')},
#  {'Street': 'Piso en calle Martinez Izquierdo',
#   'District': 'Salamanca',
#   'Property_Type': 'Piso',
#   'Price': 1000,
#   'm2': 60,
#   'Rooms': 2,
#   'location': {'type': 'Point',
#    'coordinates': [-3.665254999999999, 40.435471]},
#   '_id': ObjectId('5df7bac0ce267b38a9ae4b56')},
#  {'Street': 'Piso en calle Francisco Silvela',
#   'District': 'Salamanca',
#   'Property_Type': 'Piso',
#   'Price': 1600,
#   'm2': 120,
#   'Rooms': 3,
#   'location': {'type': 'Point', 'coordinates': [-3.671107, 40.430508]},
#   '_id': ObjectId('5df7bac0ce267b38a9ae4b57')},
#  {'Street': 'Apartamento en Embajadores-Lavapiés',
#   'District': 'Centro',
#   'Property_Type': 'Apartamento',
#   'Price': 750,
#   'm2': 26,
#   'Rooms': 1,
#   'location': {'type': 'Point', 'coordinates': [-3.6981747, 40.4081364]},
#   '_id': ObjectId('5df7bac0ce267b38a9ae4b58')},
#  {'Street': 'Ático en Palacio',
#   'District': 'Centro',
#   'Property_Type': 'Ático',
#   'Price': 3000,
#   'm2': 251,
#   'Rooms': 4,
#   'location': {'type': 'Point', 'coordinates': [-3.6971889, 40.4193576]},
#   '_id': ObjectId('5df7bac0ce267b38a9ae4b59')},
#  {'Street': 'Piso en El Viso',
#   'District': 'Chamartín',
#   'Property_Type': 'Piso',
#   'Price': 1400,
#   'm2': 95,
#   'Rooms': 3,
#   'location': {'type': 'Point', 'coordinates': [-3.6866813, 40.4490213]},
#   '_id': ObjectId('5df7bac0ce267b38a9ae4b5a')},
#  {'Street': 'Piso en calle Carlos Arniches',
#   'District': 'Centro',
#   'Property_Type': 'Piso',
#   'Price': 800,
#   'm2': 47,
#   'Rooms': 1,
#   'location': {'type': 'Point', 'coordinates': [-3.7082207, 40.4071529]},
#   '_id': ObjectId('5df7bac0ce267b38a9ae4b5b')},
#  {'Street': 'Piso en calle Ronda de Atocha, nº 12',
#   'District': 'Centro',
#   'Property_Type': 'Piso',
#   'Price': 1200,
#   'm2': 81,
#   'Rooms': 3,
#   'location': {'type': 'Point',
#    'coordinates': [-3.696592299999999, 40.4069042]},
#   '_id': ObjectId('5df7bac0ce267b38a9ae4b5c')},
#  {'Street': 'Piso en calle calle de Santa Susana',
#   'District': 'Hortaleza',
#   'Property_Type': 'Piso',
#   'Price': 780,
#   'm2': 53,
#   'Rooms': 1,
#   'location': {'type': 'Point', 'coordinates': [-3.6461722, 40.4771993]},
#   '_id': ObjectId('5df7bac0ce267b38a9ae4b5d')},
#  {'Street': 'Piso en calle Cocheras, nº 4',
#   'District': 'Retiro',
#   'Property_Type': 'Piso',
#   'Price': 1300,
#   'm2': 80,
#   'Rooms': 2,
#   'location': {'type': 'Point',
#    'coordinates': [-3.6772108, 40.40065209999999]},
#   '_id': ObjectId('5df7bac0ce267b38a9ae4b5e')},
#  {'Street': 'Piso en calle Alcala, nº 211',
#   'District': 'Salamanca',
#   'Property_Type': 'Piso',
#   'Price': 1490,
#   'm2': 85,
#   'Rooms': 2,
#   'location': {'type': 'Point', 'coordinates': [-3.6663706, 40.4294923]},
#   '_id': ObjectId('5df7bac0ce267b38a9ae4b5f')},
#  {'Street': 'Piso en calle Andres Obispo',
#   'District': 'Hortaleza',
#   'Property_Type': 'Piso',
#   'Price': 1100,
#   'm2': 70,
#   'Rooms': 2,
#   'location': {'type': 'Point', 'coordinates': [-3.6481467, 40.4641933]},
#   '_id': ObjectId('5df7bac0ce267b38a9ae4b60')},
#  {'Street': 'Piso en calle Profesor Waksman',
#   'District': 'Chamartín',
#   'Property_Type': 'Piso',
#   'Price': 3500,
#   'm2': 220,
#   'Rooms': 4,
#   'location': {'type': 'Point',
#    'coordinates': [-3.699714599999999, 40.4573172]},
#   '_id': ObjectId('5df7bac0ce267b38a9ae4b61')},
#  {'Street': 'Apartamento en calle del Doctor Castelo',
#   'District': 'Salamanca',
#   'Property_Type': 'Apartamento',
#   'Price': 1400,
#   'm2': 63,
#   'Rooms': 2,
#   'location': {'type': 'Point', 'coordinates': [-3.6747819, 40.4201976]},
#   '_id': ObjectId('5df7bac0ce267b38a9ae4b62')},
#  {'Street': 'Piso en calle Pilar de Zaragoza, nº 71',
#   'District': 'Salamanca',
#   'Property_Type': 'Piso',
#   'Price': 1400,
#   'm2': 104,
#   'Rooms': 3,
#   'location': {'type': 'Point', 'coordinates': [-3.6724621, 40.4365061]},
#   '_id': ObjectId('5df7bac0ce267b38a9ae4b63')},
#  {'Street': 'Piso en Lista',
#   'District': 'Salamanca',
#   'Property_Type': 'Piso',
#   'Price': 1100,
#   'm2': 50,
#   'Rooms': 1,
#   'location': {'type': 'Point', 'coordinates': [-3.671107, 40.430508]},
#   '_id': ObjectId('5df7bac0ce267b38a9ae4b64')},
#  {'Street': 'Ático en calle Buganvilla',
#   'District': 'Chamartín',
#   'Property_Type': 'Ático',
#   'Price': 1500,
#   'm2': 90,
#   'Rooms': 2,
#   'location': {'type': 'Point', 'coordinates': [-3.677828, 40.4723446]},
#   '_id': ObjectId('5df7bac0ce267b38a9ae4b65')},
#  {'Street': 'Piso en calle del Mesón de Paredes',
#   'District': 'Centro',
#   'Property_Type': 'Piso',
#   'Price': 1000,
#   'm2': 37,
#   'Rooms': 2,
#   'location': {'type': 'Point', 'coordinates': [-3.7010461, 40.4057018]},
#   '_id': ObjectId('5df7bac0ce267b38a9ae4b66')},
#  {'Street': 'Piso en Canillas',
#   'District': 'Hortaleza',
#   'Property_Type': 'Piso',
#   'Price': 1300,
#   'm2': 120,
#   'Rooms': 3,
#   'location': {'type': 'Point', 'coordinates': [-3.6399759, 40.4662382]},
#   '_id': ObjectId('5df7bac0ce267b38a9ae4b67')},
#  {'Street': 'Piso en calle calle de los Hermanos Bécquer',
#   'District': 'Salamanca',
#   'Property_Type': 'Piso',
#   'Price': 9000,
#   'm2': 321,
#   'Rooms': 2,
#   'location': {'type': 'Point', 'coordinates': [-3.6865147, 40.4375619]},
#   '_id': ObjectId('5df7bac0ce267b38a9ae4b68')},
#  {'Street': 'Apartamento en La Florida-Valdemarín-Aravaca',
#   'District': 'Moncloa-Aravaca',
#   'Property_Type': 'Apartamento',
#   'Price': 1899,
#   'm2': 70,
#   'Rooms': 2,
#   'location': {'type': 'Point', 'coordinates': [-3.7839264, 40.4654314]},
#   '_id': ObjectId('5df7bac0ce267b38a9ae4b69')},
#  {'Street': 'Chalet en calle calle de Peguerinos',
#   'District': 'Moncloa-Aravaca',
#   'Property_Type': 'Chalet',
#   'Price': 10000,
#   'm2': 730,
#   'Rooms': 5,
#   'location': {'type': 'Point', 'coordinates': [-3.7353762, 40.470201]},
#   '_id': ObjectId('5df7bac0ce267b38a9ae4b6a')},
#  {'Street': 'Piso en Casa de Campo',
#   'District': 'Moncloa-Aravaca',
#   'Property_Type': 'Piso',
#   'Price': 1400,
#   'm2': 83,
#   'Rooms': 3,
#   'location': {'type': 'Point', 'coordinates': [-3.7488366, 40.4197419]},
#   '_id': ObjectId('5df7bac0ce267b38a9ae4b6b')},
#  {'Street': 'Apartamento en calle calle de Santa Susana',
#   'District': 'Hortaleza',
#   'Property_Type': 'Apartamento',
#   'Price': 775,
#   'm2': 52,
#   'Rooms': 1,
#   'location': {'type': 'Point', 'coordinates': [-3.6529505, 40.4629713]},
#   '_id': ObjectId('5df7bac0ce267b38a9ae4b6c')},
#  {'Street': 'Piso en calle Doctor Esquerdo',
#   'District': 'Retiro',
#   'Property_Type': 'Piso',
#   'Price': 1200,
#   'm2': 63,
#   'Rooms': 2,
#   'location': {'type': 'Point',
#    'coordinates': [-3.672279199999999, 40.4044296]},
#   '_id': ObjectId('5df7bac0ce267b38a9ae4b6d')},
#  {'Street': 'Piso en calle calle de Ríos Rosas',
#   'District': 'Chamberí',
#   'Property_Type': 'Piso',
#   'Price': 2650,
#   'm2': 190,
#   'Rooms': 3,
#   'location': {'type': 'Point', 'coordinates': [-3.6973587, 40.4419465]},
#   '_id': ObjectId('5df7bac0ce267b38a9ae4b6e')},
#  {'Street': 'Apartamento en Salamanca',
#   'District': 'Salamanca',
#   'Property_Type': 'Apartamento',
#   'Price': 2250,
#   'm2': 90,
#   'Rooms': 2,
#   'location': {'type': 'Point',
#    'coordinates': [-5.663330999999999, 40.963884]},
#   '_id': ObjectId('5df7bac0ce267b38a9ae4b6f')},
#  {'Street': 'Piso en calle calle de Fuencarral',
#   'District': 'Chamberí',
#   'Property_Type': 'Piso',
#   'Price': 1450,
#   'm2': 41,
#   'Rooms': 1,
#   'location': {'type': 'Point', 'coordinates': [-3.7025439, 40.4299832]},
#   '_id': ObjectId('5df7bac0ce267b38a9ae4b70')},
#  {'Street': 'Piso en calle calle del Príncipe de Vergara',
#   'District': 'Salamanca',
#   'Property_Type': 'Piso',
#   'Price': 2100,
#   'm2': 123,
#   'Rooms': 3,
#   'location': {'type': 'Point', 'coordinates': [-3.679615, 40.434185]},
#   '_id': ObjectId('5df7bac0ce267b38a9ae4b71')},
#  {'Street': 'Piso en calle Paseo de La Infanta Isabel, nº 21',
#   'District': 'Retiro',
#   'Property_Type': 'Piso',
#   'Price': 1500,
#   'm2': 75,
#   'Rooms': 2,
#   'location': {'type': 'Point', 'coordinates': [-3.6869899, 40.4067791]},
#   '_id': ObjectId('5df7bac0ce267b38a9ae4b72')},
#  {'Street': 'Apartamento en Centro',
#   'District': 'Centro',
#   'Property_Type': 'Apartamento',
#   'Price': 2100,
#   'm2': 40,
#   'Rooms': 1,
#   'location': {'type': 'Point', 'coordinates': [-3.696856, 40.424815]},
#   '_id': ObjectId('5df7bac0ce267b38a9ae4b73')},
#  {'Street': 'Piso en calle Nuñez de Balboa',
#   'District': 'Salamanca',
#   'Property_Type': 'Piso',
#   'Price': 4500,
#   'm2': 156,
#   'Rooms': 2,
#   'location': {'type': 'Point', 'coordinates': [-3.6821721, 40.4281377]},
#   '_id': ObjectId('5df7bac0ce267b38a9ae4b74')},
#  {'Street': 'Piso en Salamanca - Goya',
#   'District': 'Salamanca',
#   'Property_Type': 'Piso',
#   'Price': 2300,
#   'm2': 104,
#   'Rooms': 3,
#   'location': {'type': 'Point', 'coordinates': [-3.669762, 40.4278069]},
#   '_id': ObjectId('5df7bac0ce267b38a9ae4b75')},
#  {'Street': 'Piso en calle calle de Gutiérrez Solana',
#   'District': 'Chamartín',
#   'Property_Type': 'Piso',
#   'Price': 3000,
#   'm2': 192,
#   'Rooms': 4,
#   'location': {'type': 'Point', 'coordinates': [-3.6884898, 40.450672]},
#   '_id': ObjectId('5df7bac0ce267b38a9ae4b76')},
#  {'Street': 'Apartamento en Chamartín',
#   'District': 'Chamartín',
#   'Property_Type': 'Apartamento',
#   'Price': 3500,
#   'm2': 320,
#   'Rooms': 4,
#   'location': {'type': 'Point', 'coordinates': [-3.6724928, 40.4447389]},
#   '_id': ObjectId('5df7bac1ce267b38a9ae4b77')},
#  {'Street': 'Apartamento en calle de Serrano',
#   'District': 'Salamanca',
#   'Property_Type': 'Apartamento',
#   'Price': 6500,
#   'm2': 400,
#   'Rooms': 3,
#   'location': {'type': 'Point', 'coordinates': [-3.6900327, 40.4227751]},
#   '_id': ObjectId('5df7bac1ce267b38a9ae4b78')},
#  {'Street': 'Casa en calle Ronda de Sobradiel',
#   'District': 'Hortaleza',
#   'Property_Type': 'Casa',
#   'Price': 4500,
#   'm2': 474,
#   'Rooms': 7,
#   'location': {'type': 'Point',
#    'coordinates': [-3.6420906, 40.45214420000001]},
#   '_id': ObjectId('5df7bac1ce267b38a9ae4b79')},
#  {'Street': 'Apartamento en Chamartín',
#   'District': 'Chamartín',
#   'Property_Type': 'Apartamento',
#   'Price': 1990,
#   'm2': 106,
#   'Rooms': 2,
#   'location': {'type': 'Point', 'coordinates': [-3.6724928, 40.4447389]},
#   '_id': ObjectId('5df7bac1ce267b38a9ae4b7a')},
#  {'Street': 'Piso en Chamartín - Prosperidad',
#   'District': 'Chamartín',
#   'Property_Type': 'Piso',
#   'Price': 1700,
#   'm2': 90,
#   'Rooms': 1,
#   'location': {'type': 'Point', 'coordinates': [-3.6777156, 40.4417123]},
#   '_id': ObjectId('5df7bac1ce267b38a9ae4b7b')},
#  {'Street': 'Piso en Salamanca - Goya',
#   'District': 'Salamanca',
#   'Property_Type': 'Piso',
#   'Price': 2400,
#   'm2': 136,
#   'Rooms': 3,
#   'location': {'type': 'Point', 'coordinates': [-3.669762, 40.4278069]},
#   '_id': ObjectId('5df7bac1ce267b38a9ae4b7c')},
#  {'Street': 'Dúplex en Justicia-Chueca',
#   'District': 'Centro',
#   'Property_Type': 'Dúplex',
#   'Price': 2500,
#   'm2': 126,
#   'Rooms': 2,
#   'location': {'type': 'Point', 'coordinates': [-3.6982985, 40.4207503]},
#   '_id': ObjectId('5df7bac1ce267b38a9ae4b7d')},
#  {'Street': 'Apartamento en Centro',
#   'District': 'Centro',
#   'Property_Type': 'Apartamento',
#   'Price': 2100,
#   'm2': 45,
#   'Rooms': 1,
#   'location': {'type': 'Point', 'coordinates': [-3.696856, 40.424815]},
#   '_id': ObjectId('5df7bac1ce267b38a9ae4b7e')},
#  {'Street': 'Ático en Centro - Palacio',
#   'District': 'Centro',
#   'Property_Type': 'Ático',
#   'Price': 2100,
#   'm2': 170,
#   'Rooms': 3,
#   'location': {'type': 'Point', 'coordinates': [-3.7108122, 40.4086856]},
#   '_id': ObjectId('5df7bac1ce267b38a9ae4b7f')},
#  {'Street': 'Piso en Centro - Justicia - Chueca',
#   'District': 'Centro',
#   'Property_Type': 'Piso',
#   'Price': 3000,
#   'm2': 220,
#   'Rooms': 4,
#   'location': {'type': 'Point', 'coordinates': [-3.6969823, 40.4225798]},
#   '_id': ObjectId('5df7bac1ce267b38a9ae4b80')},
#  {'Street': 'Apartamento en Centro',
#   'District': 'Centro',
#   'Property_Type': 'Apartamento',
#   'Price': 1800,
#   'm2': 100,
#   'Rooms': 2,
#   'location': {'type': 'Point', 'coordinates': [-3.696856, 40.424815]},
#   '_id': ObjectId('5df7bac1ce267b38a9ae4b81')},
#  {'Street': 'Piso en Salamanca - Recoletos',
#   'District': 'Salamanca',
#   'Property_Type': 'Piso',
#   'Price': 8700,
#   'm2': 226,
#   'Rooms': 4,
#   'location': {'type': 'Point', 'coordinates': [-3.6733793, 40.4296398]},
#   '_id': ObjectId('5df7bac1ce267b38a9ae4b82')},
#  {'Street': 'Piso en Salamanca - Goya',
#   'District': 'Salamanca',
#   'Property_Type': 'Piso',
#   'Price': 2000,
#   'm2': 150,
#   'Rooms': 3,
#   'location': {'type': 'Point', 'coordinates': [-3.669762, 40.4278069]},
#   '_id': ObjectId('5df7bac1ce267b38a9ae4b83')},
#  {'Street': 'Apartamento en Chamberí',
#   'District': 'Chamberí',
#   'Property_Type': 'Apartamento',
#   'Price': 1400,
#   'm2': 55,
#   'Rooms': 1,
#   'location': {'type': 'Point', 'coordinates': [-3.7091414, 40.4303238]},
#   '_id': ObjectId('5df7bac1ce267b38a9ae4b84')},
#  {'Street': 'Piso en calle de La Madera',
#   'District': 'Centro',
#   'Property_Type': 'Piso',
#   'Price': 850,
#   'm2': 45,
#   'Rooms': 1,
#   'location': {'type': 'Point', 'coordinates': [-3.7045119, 40.4287993]},
#   '_id': ObjectId('5df7bac1ce267b38a9ae4b85')},
#  {'Street': 'Apartamento en Salamanca',
#   'District': 'Salamanca',
#   'Property_Type': 'Apartamento',
#   'Price': 1850,
#   'm2': 105,
#   'Rooms': 1,
#   'location': {'type': 'Point',
#    'coordinates': [-5.663330999999999, 40.963884]},
#   '_id': ObjectId('5df7bac1ce267b38a9ae4b86')},
#  {'Street': 'Piso en Centro',
#   'District': 'Centro',
#   'Property_Type': 'Piso',
#   'Price': 1300,
#   'm2': 115,
#   'Rooms': 2,
#   'location': {'type': 'Point', 'coordinates': [-3.6964077, 40.403833]},
#   '_id': ObjectId('5df7bac1ce267b38a9ae4b87')},
#  {'Street': 'Apartamento en Chamberí',
#   'District': 'Chamberí',
#   'Property_Type': 'Apartamento',
#   'Price': 1890,
#   'm2': 120,
#   'Rooms': 2,
#   'location': {'type': 'Point', 'coordinates': [-3.7091414, 40.4303238]},
#   '_id': ObjectId('5df7bac1ce267b38a9ae4b88')},
#  {'Street': 'Apartamento en Salamanca',
#   'District': 'Salamanca',
#   'Property_Type': 'Apartamento',
#   'Price': 1450,
#   'm2': 120,
#   'Rooms': 2,
#   'location': {'type': 'Point',
#    'coordinates': [-5.663330999999999, 40.963884]},
#   '_id': ObjectId('5df7bac1ce267b38a9ae4b89')},
#  {'Street': 'Piso en Centro - Palacio',
#   'District': 'Centro',
#   'Property_Type': 'Piso',
#   'Price': 3600,
#   'm2': 222,
#   'Rooms': 4,
#   'location': {'type': 'Point', 'coordinates': [-3.712553, 40.4076398]},
#   '_id': ObjectId('5df7bac1ce267b38a9ae4b8a')},
#  {'Street': 'Piso en Tetuán - Cuatro Caminos - Azca',
#   'District': 'Tetuán',
#   'Property_Type': 'Piso',
#   'Price': 2300,
#   'm2': 155,
#   'Rooms': 3,
#   'location': {'type': 'Point', 'coordinates': [-3.7013532, 40.4469349]},
#   '_id': ObjectId('5df7bac1ce267b38a9ae4b8b')},
#  {'Street': 'Piso en calle de Isabel La Católica',
#   'District': 'Centro',
#   'Property_Type': 'Piso',
#   'Price': 1230,
#   'm2': 81,
#   'Rooms': 2,
#   'location': {'type': 'Point', 'coordinates': [-3.70962, 40.42132]},
#   '_id': ObjectId('5df7bac1ce267b38a9ae4b8c')},
#  {'Street': 'Apartamento en Centro',
#   'District': 'Centro',
#   'Property_Type': 'Apartamento',
#   'Price': 1495,
#   'm2': 70,
#   'Rooms': 1,
#   'location': {'type': 'Point', 'coordinates': [-3.696856, 40.424815]},
#   '_id': ObjectId('5df7bac1ce267b38a9ae4b8d')},
#  {'Street': 'Piso en Salamanca - Lista',
#   'District': 'Salamanca',
#   'Property_Type': 'Piso',
#   'Price': 4500,
#   'm2': 230,
#   'Rooms': 5,
#   'location': {'type': 'Point', 'coordinates': [-3.6733793, 40.4296398]},
#   '_id': ObjectId('5df7bac1ce267b38a9ae4b8e')},
#  {'Street': 'Apartamento en calle de Hermosilla',
#   'District': 'Salamanca',
#   'Property_Type': 'Apartamento',
#   'Price': 1750,
#   'm2': 120,
#   'Rooms': 3,
#   'location': {'type': 'Point', 'coordinates': [-3.6738469, 40.4248681]},
#   '_id': ObjectId('5df7bac1ce267b38a9ae4b8f')},
#  {'Street': 'Piso en calle Maria de Molina',
#   'District': 'Salamanca',
#   'Property_Type': 'Piso',
#   'Price': 2500,
#   'm2': 90,
#   'Rooms': 2,
#   'location': {'type': 'Point', 'coordinates': [-3.678289, 40.437085]},
#   '_id': ObjectId('5df7bac1ce267b38a9ae4b90')},
#  {'Street': 'Piso en Aravaca',
#   'District': 'Moncloa-Aravaca',
#   'Property_Type': 'Piso',
#   'Price': 1800,
#   'm2': 155,
#   'Rooms': 3,
#   'location': {'type': 'Point', 'coordinates': [-3.7843488, 40.4473406]},
#   '_id': ObjectId('5df7bac1ce267b38a9ae4b91')},
#  {'Street': 'Piso en Almagro',
#   'District': 'Chamberí',
#   'Property_Type': 'Piso',
#   'Price': 3900,
#   'm2': 137,
#   'Rooms': 3,
#   'location': {'type': 'Point', 'coordinates': [-3.6923777, 40.4306895]},
#   '_id': ObjectId('5df7bac1ce267b38a9ae4b92')},
#  {'Street': 'Piso en Justicia-Chueca',
#   'District': 'Centro',
#   'Property_Type': 'Piso',
#   'Price': 1500,
#   'm2': 67,
#   'Rooms': 1,
#   'location': {'type': 'Point', 'coordinates': [-3.6989207, 40.4234293]},
#   '_id': ObjectId('5df7bac1ce267b38a9ae4b93')},
#  {'Street': 'Dúplex en Recoletos',
#   'District': 'Salamanca',
#   'Property_Type': 'Dúplex',
#   'Price': 3500,
#   'm2': 144,
#   'Rooms': 2,
#   'location': {'type': 'Point',
#    'coordinates': [-3.6881356, 40.42140330000001]},
#   '_id': ObjectId('5df7bac1ce267b38a9ae4b94')},
#  {'Street': 'Piso en calle Lagasca',
#   'District': 'Salamanca',
#   'Property_Type': 'Piso',
#   'Price': 900,
#   'm2': 30,
#   'Rooms': 1,
#   'location': {'type': 'Point',
#    'coordinates': [-3.684739899999999, 40.4333633]},
#   '_id': ObjectId('5df7bac1ce267b38a9ae4b95')},
#  {'Street': 'Apartamento en Justicia-Chueca',
#   'District': 'Centro',
#   'Property_Type': 'Apartamento',
#   'Price': 675,
#   'm2': 40,
#   'Rooms': 1,
#   'location': {'type': 'Point', 'coordinates': [-3.6994466, 40.4228457]},
#   '_id': ObjectId('5df7bac1ce267b38a9ae4b96')},
#  {'Street': 'Piso en Plaza de Almuñecar, nº 1',
#   'District': 'Moncloa-Aravaca',
#   'Property_Type': 'Piso',
#   'Price': 995,
#   'm2': 63,
#   'Rooms': 2,
#   'location': {'type': 'Point', 'coordinates': [-3.7293114, 40.42801]},
#   '_id': ObjectId('5df7bac1ce267b38a9ae4b97')},
#  {'Street': 'Piso en Tetuan',
#   'District': 'Tetuán',
#   'Property_Type': 'Piso',
#   'Price': 1150,
#   'm2': 80,
#   'Rooms': 3,
#   'location': {'type': 'Point',
#    'coordinates': [-3.6978264, 40.45883510000001]},
#   '_id': ObjectId('5df7bac1ce267b38a9ae4b98')},
#  {'Street': 'Apartamento en calle María Pedraza',
#   'District': 'Tetuán',
#   'Property_Type': 'Apartamento',
#   'Price': 900,
#   'm2': 65,
#   'Rooms': 2,
#   'location': {'type': 'Point', 'coordinates': [-3.7100883, 40.4531535]},
#   '_id': ObjectId('5df7bac1ce267b38a9ae4b99')},
#  {'Street': 'Piso en calle calle de Calatrava',
#   'District': 'Centro',
#   'Property_Type': 'Piso',
#   'Price': 1200,
#   'm2': 100,
#   'Rooms': 3,
#   'location': {'type': 'Point', 'coordinates': [-3.7118444, 40.4093375]},
#   '_id': ObjectId('5df7bac1ce267b38a9ae4b9a')},
#  {'Street': 'Apartamento en calle Españoleto',
#   'District': 'Chamberí',
#   'Property_Type': 'Apartamento',
#   'Price': 700,
#   'm2': 35,
#   'Rooms': 1,
#   'location': {'type': 'Point', 'coordinates': [-3.6965778, 40.4293686]},
#   '_id': ObjectId('5df7bac1ce267b38a9ae4b9b')},
#  {'Street': 'Loft en calle Manuel Fernández y González',
#   'District': 'Centro',
#   'Property_Type': 'Loft',
#   'Price': 750,
#   'm2': 35,
#   'Rooms': 1,
#   'location': {'type': 'Point', 'coordinates': [-3.6995694, 40.4151568]},
#   '_id': ObjectId('5df7bac1ce267b38a9ae4b9c')},
#  {'Street': 'Piso en calle Rafael Herrera',
#   'District': 'Chamartín',
#   'Property_Type': 'Piso',
#   'Price': 1050,
#   'm2': 57,
#   'Rooms': 2,
#   'location': {'type': 'Point', 'coordinates': [-3.684839, 40.467824]},
#   '_id': ObjectId('5df7bac1ce267b38a9ae4b9d')},
#  {'Street': 'Piso en calle Alfonso XII',
#   'District': 'Retiro',
#   'Property_Type': 'Piso',
#   'Price': 2400,
#   'm2': 162,
#   'Rooms': 3,
#   'location': {'type': 'Point', 'coordinates': [-3.6888726, 40.4082002]},
#   '_id': ObjectId('5df7bac1ce267b38a9ae4b9e')},
#  {'Street': 'Apartamento en calle Gran Vía, nº 68',
#   'District': 'Centro',
#   'Property_Type': 'Apartamento',
#   'Price': 2000,
#   'm2': 82,
#   'Rooms': 1,
#   'location': {'type': 'Point',
#    'coordinates': [-3.709053299999999, 40.422017]},
#   '_id': ObjectId('5df7bac1ce267b38a9ae4b9f')},
#  {'Street': 'Piso en calle General Yagüe',
#   'District': 'Tetuán',
#   'Property_Type': 'Piso',
#   'Price': 2300,
#   'm2': 125,
#   'Rooms': 2,
#   'location': {'type': 'Point', 'coordinates': [-3.6990358, 40.4568375]},
#   '_id': ObjectId('5df7bac1ce267b38a9ae4ba0')},
#  {'Street': 'Apartamento en calle San Vicente Ferrer',
#   'District': 'Centro',
#   'Property_Type': 'Apartamento',
#   'Price': 840,
#   'm2': 34,
#   'Rooms': 1,
#   'location': {'type': 'Point',
#    'coordinates': [-3.701216999999999, 40.4254533]},
#   '_id': ObjectId('5df7bac1ce267b38a9ae4ba1')},
#  {'Street': 'Piso en calle Infanta Maria Teresa, nº 6',
#   'District': 'Chamartín',
#   'Property_Type': 'Piso',
#   'Price': 2600,
#   'm2': 120,
#   'Rooms': 3,
#   'location': {'type': 'Point',
#    'coordinates': [-3.682097499999999, 40.4540278]},
#   '_id': ObjectId('5df7bac1ce267b38a9ae4ba2')},
#  {'Street': 'Piso en calle Valdemarin',
#   'District': 'Moncloa-Aravaca',
#   'Property_Type': 'Piso',
#   'Price': 2250,
#   'm2': 155,
#   'Rooms': 4,
#   'location': {'type': 'Point',
#    'coordinates': [-3.7831149, 40.47198700000001]},
#   '_id': ObjectId('5df7bac1ce267b38a9ae4ba3')},
#  {'Street': 'Ático en calle de Don Ramón de La Cruz',
#   'District': 'Salamanca',
#   'Property_Type': 'Ático',
#   'Price': 2100,
#   'm2': 143,
#   'Rooms': 2,
#   'location': {'type': 'Point', 'coordinates': [-3.6804439, 40.4290432]},
#   '_id': ObjectId('5df7bac1ce267b38a9ae4ba4')},
#  {'Street': 'Piso en Almagro',
#   'District': 'Chamberí',
#   'Property_Type': 'Piso',
#   'Price': 3300,
#   'm2': 140,
#   'Rooms': 2,
#   'location': {'type': 'Point', 'coordinates': [-3.6923777, 40.4306895]},
#   '_id': ObjectId('5df7bac1ce267b38a9ae4ba5')},
#  {'Street': 'Piso en calle Alfonso XII',
#   'District': 'Retiro',
#   'Property_Type': 'Piso',
#   'Price': 4400,
#   'm2': 240,
#   'Rooms': 5,
#   'location': {'type': 'Point', 'coordinates': [-3.6888726, 40.4082002]},
#   '_id': ObjectId('5df7bac1ce267b38a9ae4ba6')},
#  {'Street': 'Piso en calle Monte Esquinza, nº 34',
#   'District': 'Chamberí',
#   'Property_Type': 'Piso',
#   'Price': 4200,
#   'm2': 220,
#   'Rooms': 4,
#   'location': {'type': 'Point',
#    'coordinates': [-3.6917842, 40.42999349999999]},
#   '_id': ObjectId('5df7bac1ce267b38a9ae4ba7')},
#  {'Street': 'Piso en calle Palmera, nº 12',
#   'District': 'Tetuán',
#   'Property_Type': 'Piso',
#   'Price': 975,
#   'm2': 68,
#   'Rooms': 2,
#   'location': {'type': 'Point', 'coordinates': [-3.6920991, 40.4720673]},
#   '_id': ObjectId('5df7bac1ce267b38a9ae4ba8')},
#  {'Street': 'Piso en calle Rodríguez San Pedro',
#   'District': 'Chamberí',
#   'Property_Type': 'Piso',
#   'Price': 1250,
#   'm2': 60,
#   'Rooms': 1,
#   'location': {'type': 'Point', 'coordinates': [-3.7108328, 40.431774]},
#   '_id': ObjectId('5df7bac1ce267b38a9ae4ba9')},
#  {'Street': 'Apartamento en calle Orense',
#   'District': 'Tetuán',
#   'Property_Type': 'Apartamento',
#   'Price': 1650,
#   'm2': 70,
#   'Rooms': 1,
#   'location': {'type': 'Point', 'coordinates': [-3.6947215, 40.4587822]},
#   '_id': ObjectId('5df7bac1ce267b38a9ae4baa')},
#  {'Street': 'Piso en calle calle Alcalde Sainz de Baranda',
#   'District': 'Retiro',
#   'Property_Type': 'Piso',
#   'Price': 1400,
#   'm2': 72,
#   'Rooms': 2,
#   'location': {'type': 'Point', 'coordinates': [-3.669415, 40.41614]},
#   '_id': ObjectId('5df7bac1ce267b38a9ae4bab')},
#  {'Street': 'Apartamento en Avenida del Mediterráneo',
#   'District': 'Retiro',
#   'Property_Type': 'Apartamento',
#   'Price': 1050,
#   'm2': 68,
#   'Rooms': 2,
#   'location': {'type': 'Point',
#    'coordinates': [-3.6690037, 40.40179759999999]},
#   '_id': ObjectId('5df7bac1ce267b38a9ae4bac')},
#  {'Street': 'Piso en calle Aguirre, nº 3',
#   'District': 'Salamanca',
#   'Property_Type': 'Piso',
#   'Price': 1750,
#   'm2': 75,
#   'Rooms': 2,
#   'location': {'type': 'Point', 'coordinates': [-3.6812409, 40.4218268]},
#   '_id': ObjectId('5df7bac1ce267b38a9ae4bad')},
#  {'Street': 'Apartamento en Avenida del Talgo, nº 81',
#   'District': 'Moncloa-Aravaca',
#   'Property_Type': 'Apartamento',
#   'Price': 1300,
#   'm2': 95,
#   'Rooms': 2,
#   'location': {'type': 'Point', 'coordinates': [-3.7853902, 40.4470812]},
#   '_id': ObjectId('5df7bac1ce267b38a9ae4bae')},
#  {'Street': 'Piso en Avenida Juan de Andres, nº 15',
#   'District': 'Moncloa-Aravaca',
#   'Property_Type': 'Piso',
#   'Price': 710,
#   'm2': 40,
#   'Rooms': 1,
#   'location': {'type': 'Point',
#    'coordinates': [-3.723160899999999, 40.4678362]},
#   '_id': ObjectId('5df7bac1ce267b38a9ae4baf')},
#  {'Street': 'Piso en Salamanca - Recoletos',
#   'District': 'Salamanca',
#   'Property_Type': 'Piso',
#   'Price': 2800,
#   'm2': 147,
#   'Rooms': 3,
#   'location': {'type': 'Point', 'coordinates': [-3.6733793, 40.4296398]},
#   '_id': ObjectId('5df7bac1ce267b38a9ae4bb0')},
#  {'Street': 'Apartamento en calle de La Aduana',
#   'District': 'Centro',
#   'Property_Type': 'Apartamento',
#   'Price': 850,
#   'm2': 40,
#   'Rooms': 1,
#   'location': {'type': 'Point',
#    'coordinates': [-3.701460599999999, 40.4183278]},
#   '_id': ObjectId('5df7bac1ce267b38a9ae4bb1')},
#  {'Street': 'Apartamento en calle Alfonso XII',
#   'District': 'Retiro',
#   'Property_Type': 'Apartamento',
#   'Price': 1100,
#   'm2': 59,
#   'Rooms': 1,
#   'location': {'type': 'Point', 'coordinates': [-3.6891862, 40.4163427]},
#   '_id': ObjectId('5df7bac1ce267b38a9ae4bb2')},
#  {'Street': 'Apartamento en calle Juan Álvarez Mendizabal, nº 51',
#   'District': 'Moncloa-Aravaca',
#   'Property_Type': 'Apartamento',
#   'Price': 1150,
#   'm2': 52,
#   'Rooms': 1,
#   'location': {'type': 'Point', 'coordinates': [-3.7163996, 40.426581]},
#   '_id': ObjectId('5df7bac1ce267b38a9ae4bb3')},
#  {'Street': 'Ático en calle Buganvilla',
#   'District': 'Chamartín',
#   'Property_Type': 'Ático',
#   'Price': 1500,
#   'm2': 90,
#   'Rooms': 2,
#   'location': {'type': 'Point', 'coordinates': [-3.677828, 40.4723446]},
#   '_id': ObjectId('5df7bac1ce267b38a9ae4bb4')},
#  {'Street': 'Apartamento en calle de Ríos Rosas',
#   'District': 'Chamberí',
#   'Property_Type': 'Apartamento',
#   'Price': 2650,
#   'm2': 190,
#   'Rooms': 3,
#   'location': {'type': 'Point', 'coordinates': [-3.7014559, 40.441724]},
#   '_id': ObjectId('5df7bac1ce267b38a9ae4bb5')},
#  {'Street': 'Piso en calle Platerias, nº 4',
#   'District': 'Chamartín',
#   'Property_Type': 'Piso',
#   'Price': 3500,
#   'm2': 389,
#   'Rooms': 6,
#   'location': {'type': 'Point', 'coordinates': [-3.6777343, 40.4674595]},
#   '_id': ObjectId('5df7bac1ce267b38a9ae4bb6')},
#  {'Street': 'Apartamento en calle de Las Infantas',
#   'District': 'Centro',
#   'Property_Type': 'Apartamento',
#   'Price': 2500,
#   'm2': 200,
#   'Rooms': 4,
#   'location': {'type': 'Point', 'coordinates': [-3.7006038, 40.4207985]},
#   '_id': ObjectId('5df7bac1ce267b38a9ae4bb7')},
#  {'Street': 'Estudio en Avenida Filipinas, nº 1 Bis',
#   'District': 'Chamberí',
#   'Property_Type': 'Estudio',
#   'Price': 800,
#   'm2': 38,
#   'Rooms': 1,
#   'location': {'type': 'Point', 'coordinates': [-3.7125385, 40.4394342]},
#   '_id': ObjectId('5df7bac1ce267b38a9ae4bb8')},
#  {'Street': 'Piso en calle de Ferraz',
#   'District': 'Moncloa-Aravaca',
#   'Property_Type': 'Piso',
#   'Price': 2350,
#   'm2': 140,
#   'Rooms': 3,
#   'location': {'type': 'Point',
#    'coordinates': [-3.7198331, 40.42857540000001]},
#   '_id': ObjectId('5df7bac1ce267b38a9ae4bb9')},
#  {'Street': 'Piso en Arapiles',
#   'District': 'Chamberí',
#   'Property_Type': 'Piso',
#   'Price': 1000,
#   'm2': 60,
#   'Rooms': 2,
#   'location': {'type': 'Point',
#    'coordinates': [-3.7086506, 40.43512459999999]},
#   '_id': ObjectId('5df7bac1ce267b38a9ae4bba')},
#  {'Street': 'Piso en calle Raimundo Fenández Villaverde',
#   'District': 'Tetuán',
#   'Property_Type': 'Piso',
#   'Price': 2500,
#   'm2': 125,
#   'Rooms': 2,
#   'location': {'type': 'Point', 'coordinates': [-3.7013532, 40.4469349]},
#   '_id': ObjectId('5df7bac1ce267b38a9ae4bbb')},
#  {'Street': 'Piso en Paseo Paseo de La Habana 26',
#   'District': 'Chamartín',
#   'Property_Type': 'Piso',
#   'Price': 1500,
#   'm2': 60,
#   'Rooms': 2,
#   'location': {'type': 'Point', 'coordinates': [-3.6888456, 40.4488613]},
#   '_id': ObjectId('5df7bac1ce267b38a9ae4bbc')},
#  {'Street': 'Piso en calle Alcala',
#   'District': 'Salamanca',
#   'Property_Type': 'Piso',
#   'Price': 1200,
#   'm2': 64,
#   'Rooms': 2,
#   'location': {'type': 'Point', 'coordinates': [-3.646351, 40.43412060000001]},
#   '_id': ObjectId('5df7bac1ce267b38a9ae4bbd')},
#  {'Street': 'Apartamento en calle de Pizarro, nº 5',
#   'District': 'Centro',
#   'Property_Type': 'Apartamento',
#   'Price': 1200,
#   'm2': 50,
#   'Rooms': 2,
#   'location': {'type': 'Point', 'coordinates': [-3.70578, 40.423344]},
#   '_id': ObjectId('5df7bac1ce267b38a9ae4bbe')},
#  {'Street': 'Piso en Paseo de La Castellana, nº 100',
#   'District': 'Chamartín',
#   'Property_Type': 'Piso',
#   'Price': 2800,
#   'm2': 212,
#   'Rooms': 3,
#   'location': {'type': 'Point',
#    'coordinates': [-3.690781399999999, 40.4443748]},
#   '_id': ObjectId('5df7bac1ce267b38a9ae4bbf')},
#  {'Street': 'Apartamento en Almagro',
#   'District': 'Chamberí',
#   'Property_Type': 'Apartamento',
#   'Price': 3500,
#   'm2': 166,
#   'Rooms': 3,
#   'location': {'type': 'Point', 'coordinates': [-3.7135661, 38.8876251]},
#   '_id': ObjectId('5df7bac1ce267b38a9ae4bc0')},
#  {'Street': 'Apartamento en calle San Lorenzo',
#   'District': 'Centro',
#   'Property_Type': 'Apartamento',
#   'Price': 1800,
#   'm2': 103,
#   'Rooms': 4,
#   'location': {'type': 'Point', 'coordinates': [-3.698336, 40.4248143]},
#   '_id': ObjectId('5df7bac1ce267b38a9ae4bc1')},
#  {'Street': 'Piso en calle Jerónimo de La Quintana, nº 11',
#   'District': 'Chamberí',
#   'Property_Type': 'Piso',
#   'Price': 1850,
#   'm2': 100,
#   'Rooms': 3,
#   'location': {'type': 'Point', 'coordinates': [-3.7046841, 40.4313158]},
#   '_id': ObjectId('5df7bac1ce267b38a9ae4bc2')},
#  {'Street': 'Piso en Hispanoamérica',
#   'District': 'Chamartín',
#   'Property_Type': 'Piso',
#   'Price': 2990,
#   'm2': 220,
#   'Rooms': 4,
#   'location': {'type': 'Point', 'coordinates': [-3.6742557, 40.4521575]},
#   '_id': ObjectId('5df7bac1ce267b38a9ae4bc3')},
#  {'Street': 'Apartamento en calle de Núñez de Balboa',
#   'District': 'Retiro',
#   'Property_Type': 'Apartamento',
#   'Price': 3200,
#   'm2': 125,
#   'Rooms': 2,
#   'location': {'type': 'Point', 'coordinates': [-3.683122, 40.422782]},
#   '_id': ObjectId('5df7bac1ce267b38a9ae4bc4')},
#  {'Street': 'Piso en calle de Ferraz, nº 43',
#   'District': 'Moncloa-Aravaca',
#   'Property_Type': 'Piso',
#   'Price': 1375,
#   'm2': 80,
#   'Rooms': 2,
#   'location': {'type': 'Point', 'coordinates': [-3.720354, 40.4288895]},
#   '_id': ObjectId('5df7bac1ce267b38a9ae4bc5')},
#  {'Street': 'Piso en calle Medellin',
#   'District': 'Chamberí',
#   'Property_Type': 'Piso',
#   'Price': 1150,
#   'm2': 66,
#   'Rooms': 1,
#   'location': {'type': 'Point', 'coordinates': [-3.6995308, 40.4390319]},
#   '_id': ObjectId('5df7bac1ce267b38a9ae4bc6')},
#  {'Street': 'Piso en calle San Benito, nº 49',
#   'District': 'Tetuán',
#   'Property_Type': 'Piso',
#   'Price': 1150,
#   'm2': 80,
#   'Rooms': 2,
#   'location': {'type': 'Point', 'coordinates': [-3.6955667, 40.4707472]},
#   '_id': ObjectId('5df7bac1ce267b38a9ae4bc7')},
#  {'Street': 'Piso en Sanchinarro',
#   'District': 'Hortaleza',
#   'Property_Type': 'Piso',
#   'Price': 1400,
#   'm2': 115,
#   'Rooms': 3,
#   'location': {'type': 'Point', 'coordinates': [-3.6508781, 40.4898353]},
#   '_id': ObjectId('5df7bac1ce267b38a9ae4bc8')},
#  {'Street': 'Piso en Avenida Francisco Javier Sáenz de Oiza, nº 50',
#   'District': 'Hortaleza',
#   'Property_Type': 'Piso',
#   'Price': 1800,
#   'm2': 130,
#   'Rooms': 3,
#   'location': {'type': 'Point', 'coordinates': [-3.6178552, 40.4980473]},
#   '_id': ObjectId('5df7bac1ce267b38a9ae4bc9')},
#  {'Street': '1500 €/semPiso en calle Siete de Julio',
#   'District': 'Centro',
#   'Property_Type': 'Piso',
#   'Price': 1500,
#   'm2': 80,
#   'Rooms': 2,
#   'location': {'type': 'Point',
#    'coordinates': [-3.7079546, 40.41583749999999]},
#   '_id': ObjectId('5df7bac1ce267b38a9ae4bca')},
#  {'Street': 'Apartamento en calle Cardenal Cisneros, nº 75',
#   'District': 'Chamberí',
#   'Property_Type': 'Apartamento',
#   'Price': 850,
#   'm2': 42,
#   'Rooms': 1,
#   'location': {'type': 'Point', 'coordinates': [-3.6986848, 40.4328946]},
#   '_id': ObjectId('5df7bac1ce267b38a9ae4bcb')},
#  {'Street': 'Ático en calle Sagasta',
#   'District': 'Centro',
#   'Property_Type': 'Ático',
#   'Price': 8500,
#   'm2': 350,
#   'Rooms': 4,
#   'location': {'type': 'Point', 'coordinates': [-3.6994911, 40.4194369]},
#   '_id': ObjectId('5df7bac1ce267b38a9ae4bcc')},
#  {'Street': 'Apartamento en calle Francos Rodríguez, nº 88',
#   'District': 'Tetuán',
#   'Property_Type': 'Apartamento',
#   'Price': 850,
#   'm2': 50,
#   'Rooms': 1,
#   'location': {'type': 'Point', 'coordinates': [-3.6993042, 40.4587417]},
#   '_id': ObjectId('5df7bac1ce267b38a9ae4bcd')},
#  {'Street': 'Piso en calle de Sta Hortensia',
#   'District': 'Chamartín',
#   'Property_Type': 'Piso',
#   'Price': 1800,
#   'm2': 100,
#   'Rooms': 4,
#   'location': {'type': 'Point', 'coordinates': [-3.6628142, 40.4456943]},
#   '_id': ObjectId('5df7bac1ce267b38a9ae4bce')},
#  {'Street': 'Piso en calle Raimundo Fernandez Villaverde',
#   'District': 'Chamberí',
#   'Property_Type': 'Piso',
#   'Price': 2500,
#   'm2': 165,
#   'Rooms': 4,
#   'location': {'type': 'Point', 'coordinates': [-3.7013532, 40.4469349]},
#   '_id': ObjectId('5df7bac1ce267b38a9ae4bcf')},
#  {'Street': 'Chalet en calle de Laurín',
#   'District': 'Hortaleza',
#   'Property_Type': 'Chalet',
#   'Price': 3200,
#   'm2': 295,
#   'Rooms': 6,
#   'location': {'type': 'Point', 'coordinates': [-3.6488145, 40.4576331]},
#   '_id': ObjectId('5df7bac1ce267b38a9ae4bd0')},
#  {'Street': 'Apartamento en calle Orense, nº 10',
#   'District': 'Tetuán',
#   'Property_Type': 'Apartamento',
#   'Price': 2800,
#   'm2': 180,
#   'Rooms': 3,
#   'location': {'type': 'Point', 'coordinates': [-3.6947215, 40.4587822]},
#   '_id': ObjectId('5df7bac1ce267b38a9ae4bd1')},
#  {'Street': 'Ático en Universidad-Malasaña',
#   'District': 'Centro',
#   'Property_Type': 'Ático',
#   'Price': 670,
#   'm2': 30,
#   'Rooms': 1,
#   'location': {'type': 'Point', 'coordinates': [-3.695596, 40.415903]},
#   '_id': ObjectId('5df7bac1ce267b38a9ae4bd2')},
#  {'Street': 'Apartamento en Salamanca',
#   'District': 'Salamanca',
#   'Property_Type': 'Apartamento',
#   'Price': 2100,
#   'm2': 123,
#   'Rooms': 3,
#   'location': {'type': 'Point',
#    'coordinates': [-5.663330999999999, 40.963884]},
#   '_id': ObjectId('5df7bac1ce267b38a9ae4bd3')},
#  {'Street': 'Piso en calle del Corazón de María',
#   'District': 'Chamartín',
#   'Property_Type': 'Piso',
#   'Price': 1150,
#   'm2': 64,
#   'Rooms': 2,
#   'location': {'type': 'Point', 'coordinates': [-3.678289, 40.437085]},
#   '_id': ObjectId('5df7bac1ce267b38a9ae4bd4')},
#  {'Street': 'Piso en calle  O´Donnell 46',
#   'District': 'Salamanca',
#   'Property_Type': 'Piso',
#   'Price': 2140,
#   'm2': 150,
#   'Rooms': 4,
#   'location': {'type': 'Point', 'coordinates': [-3.6732492, 40.4211941]},
#   '_id': ObjectId('5df7bac1ce267b38a9ae4bd5')},
#  {'Street': 'Piso en calle Orfila',
#   'District': 'Chamberí',
#   'Property_Type': 'Piso',
#   'Price': 1200,
#   'm2': 49,
#   'Rooms': 1,
#   'location': {'type': 'Point', 'coordinates': [-3.7045119, 40.4287993]},
#   '_id': ObjectId('5df7bac1ce267b38a9ae4bd6')},
#  {'Street': 'Piso en calle calle de Mauricio Legendre, nº 29',
#   'District': 'Chamartín',
#   'Property_Type': 'Piso',
#   'Price': 1250,
#   'm2': 66,
#   'Rooms': 2,
#   'location': {'type': 'Point', 'coordinates': [-3.6861571, 40.4722645]},
#   '_id': ObjectId('5df7bac1ce267b38a9ae4bd7')},
#  {'Street': 'Apartamento en Chamartín',
#   'District': 'Chamartín',
#   'Property_Type': 'Apartamento',
#   'Price': 1100,
#   'm2': 49,
#   'Rooms': 1,
#   'location': {'type': 'Point', 'coordinates': [-3.6724928, 40.4447389]},
#   '_id': ObjectId('5df7bac1ce267b38a9ae4bd8')},
#  {'Street': 'Piso en calle Ambrosio Vallejo, nº 22',
#   'District': 'Tetuán',
#   'Property_Type': 'Piso',
#   'Price': 750,
#   'm2': 35,
#   'Rooms': 1,
#   'location': {'type': 'Point', 'coordinates': [-3.7081133, 40.4573344]},
#   '_id': ObjectId('5df7bac1ce267b38a9ae4bd9')},
#  {'Street': 'Piso en calle Maestro Alonso, nº 17',
#   'District': 'Salamanca',
#   'Property_Type': 'Piso',
#   'Price': 1650,
#   'm2': 79,
#   'Rooms': 3,
#   'location': {'type': 'Point', 'coordinates': [-3.6639479, 40.4286357]},
#   '_id': ObjectId('5df7bac1ce267b38a9ae4bda')},
#  {'Street': 'Apartamento en calle de Andres Mellado, nº 82',
#   'District': 'Chamberí',
#   'Property_Type': 'Apartamento',
#   'Price': 1400,
#   'm2': 80,
#   'Rooms': 2,
#   'location': {'type': 'Point', 'coordinates': [-3.7140765, 40.4378825]},
#   '_id': ObjectId('5df7bac1ce267b38a9ae4bdb')},
#  {'Street': 'Piso en calle Madera, nº 30',
#   'District': 'Centro',
#   'Property_Type': 'Piso',
#   'Price': 795,
#   'm2': 35,
#   'Rooms': 1,
#   'location': {'type': 'Point', 'coordinates': [-3.7038192, 40.4240054]},
#   '_id': ObjectId('5df7bac1ce267b38a9ae4bdc')},
#  {'Street': 'Dúplex en calle Segre',
#   'District': 'Chamartín',
#   'Property_Type': 'Dúplex',
#   'Price': 4300,
#   'm2': 248,
#   'Rooms': 3,
#   'location': {'type': 'Point',
#    'coordinates': [-3.6838742, 40.45088680000001]},
#   '_id': ObjectId('5df7bac1ce267b38a9ae4bdd')},
#  {'Street': 'Apartamento en calle Ballesta',
#   'District': 'Centro',
#   'Property_Type': 'Apartamento',
#   'Price': 1100,
#   'm2': 40,
#   'Rooms': 2,
#   'location': {'type': 'Point',
#    'coordinates': [-3.7035898, 40.42274870000001]},
#   '_id': ObjectId('5df7bac1ce267b38a9ae4bde')},
#  {'Street': 'Piso en Universidad',
#   'District': 'Centro',
#   'Property_Type': 'Piso',
#   'Price': 1200,
#   'm2': 63,
#   'Rooms': 3,
#   'location': {'type': 'Point', 'coordinates': [-3.706918, 40.424238]},
#   '_id': ObjectId('5df7bac1ce267b38a9ae4bdf')},
#  {'Street': 'Piso en calle Serrano',
#   'District': 'Salamanca',
#   'Property_Type': 'Piso',
#   'Price': 3600,
#   'm2': 136,
#   'Rooms': 3,
#   'location': {'type': 'Point', 'coordinates': [-3.6865147, 40.4375619]},
#   '_id': ObjectId('5df7bac1ce267b38a9ae4be0')},
#  {'Street': 'Dúplex en calle Corredera Baja de San Pablo',
#   'District': 'Centro',
#   'Property_Type': 'Dúplex',
#   'Price': 3000,
#   'm2': 202,
#   'Rooms': 2,
#   'location': {'type': 'Point', 'coordinates': [-3.7037051, 40.4225791]},
#   '_id': ObjectId('5df7bac1ce267b38a9ae4be1')},
#  {'Street': 'Piso en calle Don Quijote, nº 40',
#   'District': 'Tetuán',
#   'Property_Type': 'Piso',
#   'Price': 1150,
#   'm2': 80,
#   'Rooms': 2,
#   'location': {'type': 'Point', 'coordinates': [-3.6989659, 40.4493325]},
#   '_id': ObjectId('5df7bac1ce267b38a9ae4be2')},
#  {'Street': 'Piso en calle Orense, nº 6',
#   'District': 'Tetuán',
#   'Property_Type': 'Piso',
#   'Price': 1950,
#   'm2': 98,
#   'Rooms': 2,
#   'location': {'type': 'Point', 'coordinates': [-3.6952201, 40.4479462]},
#   '_id': ObjectId('5df7bac1ce267b38a9ae4be3')},
#  {'Street': 'Piso en calle Talavera',
#   'District': 'Chamartín',
#   'Property_Type': 'Piso',
#   'Price': 1150,
#   'm2': 58,
#   'Rooms': 1,
#   'location': {'type': 'Point', 'coordinates': [-3.6862323, 40.4380946]},
#   '_id': ObjectId('5df7bac1ce267b38a9ae4be4')},
#  {'Street': 'Piso en Goya',
#   'District': 'Salamanca',
#   'Property_Type': 'Piso',
#   'Price': 2050,
#   'm2': 134,
#   'Rooms': 3,
#   'location': {'type': 'Point', 'coordinates': [-3.6807456, 40.4248439]},
#   '_id': ObjectId('5df7bac1ce267b38a9ae4be5')},
#  {'Street': 'Apartamento en calle Ramos Carrion',
#   'District': 'Chamartín',
#   'Property_Type': 'Apartamento',
#   'Price': 1480,
#   'm2': 117,
#   'Rooms': 4,
#   'location': {'type': 'Point',
#    'coordinates': [-3.6693286, 40.44674990000001]},
#   '_id': ObjectId('5df7bac1ce267b38a9ae4be6')},
#  {'Street': 'Piso en calle Treviño',
#   'District': 'Chamberí',
#   'Property_Type': 'Piso',
#   'Price': 1250,
#   'm2': 64,
#   'Rooms': 2,
#   'location': {'type': 'Point',
#    'coordinates': [-3.7038309, 40.44402729999999]},
#   '_id': ObjectId('5df7bac1ce267b38a9ae4be7')},
#  {'Street': 'Ático en Chamartín',
#   'District': 'Chamartín',
#   'Property_Type': 'Ático',
#   'Price': 1300,
#   'm2': 72,
#   'Rooms': 3,
#   'location': {'type': 'Point', 'coordinates': [-3.6855729, 40.4697982]},
#   '_id': ObjectId('5df7bac1ce267b38a9ae4be8')},
#  {'Street': 'Casa en calle Abedul',
#   'District': 'Chamartín',
#   'Property_Type': 'Casa',
#   'Price': 5600,
#   'm2': 403,
#   'Rooms': 4,
#   'location': {'type': 'Point', 'coordinates': [-3.622843, 40.381305]},
#   '_id': ObjectId('5df7bac1ce267b38a9ae4be9')},
#  {'Street': 'Piso en calle Oña',
#   'District': 'Hortaleza',
#   'Property_Type': 'Piso',
#   'Price': 1200,
#   'm2': 130,
#   'Rooms': 3,
#   'location': {'type': 'Point',
#    'coordinates': [-3.6684145, 40.48883989999999]},
#   '_id': ObjectId('5df7bac1ce267b38a9ae4bea')},
#  {'Street': 'Apartamento en calle Jardines',
#   'District': 'Centro',
#   'Property_Type': 'Apartamento',
#   'Price': 800,
#   'm2': 51,
#   'Rooms': 1,
#   'location': {'type': 'Point', 'coordinates': [-3.7009215, 40.4188519]},
#   '_id': ObjectId('5df7bac1ce267b38a9ae4beb')},
#  {'Street': 'Piso en calle de Hortaleza',
#   'District': 'Centro',
#   'Property_Type': 'Piso',
#   'Price': 1300,
#   'm2': 80,
#   'Rooms': 2,
#   'location': {'type': 'Point', 'coordinates': [-3.6989207, 40.4234293]},
#   '_id': ObjectId('5df7bac1ce267b38a9ae4bec')},
#  {'Street': 'Piso en Sanchinarro',
#   'District': 'Hortaleza',
#   'Property_Type': 'Piso',
#   'Price': 1200,
#   'm2': 85,
#   'Rooms': 2,
#   'location': {'type': 'Point', 'coordinates': [-3.6508781, 40.4898353]},
#   '_id': ObjectId('5df7bac1ce267b38a9ae4bed')},
#  {'Street': 'Piso en calle Navas',
#   'District': 'Tetuán',
#   'Property_Type': 'Piso',
#   'Price': 750,
#   'm2': 34,
#   'Rooms': 1,
#   'location': {'type': 'Point', 'coordinates': [-3.6975, 40.4597511]},
#   '_id': ObjectId('5df7bac1ce267b38a9ae4bee')},
#  {'Street': 'Apartamento en calle del Barquillo',
#   'District': 'Centro',
#   'Property_Type': 'Apartamento',
#   'Price': 2880,
#   'm2': 133,
#   'Rooms': 2,
#   'location': {'type': 'Point', 'coordinates': [-3.6957851, 40.4228348]},
#   '_id': ObjectId('5df7bac1ce267b38a9ae4bef')},
#  {'Street': 'Apartamento en calle Ana María',
#   'District': 'Tetuán',
#   'Property_Type': 'Apartamento',
#   'Price': 870,
#   'm2': 49,
#   'Rooms': 1,
#   'location': {'type': 'Point', 'coordinates': [-3.6941619, 40.4646313]},
#   '_id': ObjectId('5df7bac1ce267b38a9ae4bf0')},
#  {'Street': 'Piso en Arturo  Soria',
#   'District': 'Hortaleza',
#   'Property_Type': 'Piso',
#   'Price': 3900,
#   'm2': 300,
#   'Rooms': 5,
#   'location': {'type': 'Point', 'coordinates': [-3.6428201, 40.4431532]},
#   '_id': ObjectId('5df7bac1ce267b38a9ae4bf1')},
#  {'Street': 'Piso en calle Leñeros',
#   'District': 'Tetuán',
#   'Property_Type': 'Piso',
#   'Price': 850,
#   'm2': 51,
#   'Rooms': 1,
#   'location': {'type': 'Point', 'coordinates': [-3.7089197, 40.4526738]},
#   '_id': ObjectId('5df7bac1ce267b38a9ae4bf2')},
#  {'Street': 'Piso en Universidad-Malasaña',
#   'District': 'Centro',
#   'Property_Type': 'Piso',
#   'Price': 750,
#   'm2': 30,
#   'Rooms': 1,
#   'location': {'type': 'Point', 'coordinates': [-3.706918, 40.424238]},
#   '_id': ObjectId('5df7bac1ce267b38a9ae4bf3')},
#  {'Street': 'Piso en calle Fuente del Berro',
#   'District': 'Salamanca',
#   'Property_Type': 'Piso',
#   'Price': 1950,
#   'm2': 142,
#   'Rooms': 3,
#   'location': {'type': 'Point', 'coordinates': [-3.6681159, 40.4267599]},
#   '_id': ObjectId('5df7bac1ce267b38a9ae4bf4')},
#  {'Street': 'Ático en calle Luisa Fernanda, nº 20',
#   'District': 'Moncloa-Aravaca',
#   'Property_Type': 'Ático',
#   'Price': 1800,
#   'm2': 110,
#   'Rooms': 2,
#   'location': {'type': 'Point', 'coordinates': [-3.7157357, 40.4250627]},
#   '_id': ObjectId('5df7bac1ce267b38a9ae4bf5')},
#  {'Street': 'Estudio en Ríos Rosas',
#   'District': 'Chamberí',
#   'Property_Type': 'Estudio',
#   'Price': 750,
#   'm2': 28,
#   'Rooms': 1,
#   'location': {'type': 'Point', 'coordinates': [-3.6994617, 40.4420305]},
#   '_id': ObjectId('5df7bac1ce267b38a9ae4bf6')},
#  {'Street': 'Piso en Cuatro Caminos',
#   'District': 'Tetuán',
#   'Property_Type': 'Piso',
#   'Price': 1500,
#   'm2': 78,
#   'Rooms': 2,
#   'location': {'type': 'Point', 'coordinates': [-3.7013532, 40.4469349]},
#   '_id': ObjectId('5df7bac1ce267b38a9ae4bf7')},
#  {'Street': 'Apartamento en calle Jorge Juan',
#   'District': 'Salamanca',
#   'Property_Type': 'Apartamento',
#   'Price': 2200,
#   'm2': 123,
#   'Rooms': 3,
#   'location': {'type': 'Point', 'coordinates': [-3.6796572, 40.4232011]},
#   '_id': ObjectId('5df7bac1ce267b38a9ae4bf8')},
#  {'Street': 'Piso en calle Lope de Vega',
#   'District': 'Centro',
#   'Property_Type': 'Piso',
#   'Price': 1400,
#   'm2': 110,
#   'Rooms': 2,
#   'location': {'type': 'Point', 'coordinates': [-3.6983821, 40.4138922]},
#   '_id': ObjectId('5df7bac1ce267b38a9ae4bf9')},
#  {'Street': 'Piso en calle Francisco Navacerrada',
#   'District': 'Salamanca',
#   'Property_Type': 'Piso',
#   'Price': 1100,
#   'm2': 73,
#   'Rooms': 1,
#   'location': {'type': 'Point', 'coordinates': [-3.671107, 40.430508]},
#   '_id': ObjectId('5df7bac1ce267b38a9ae4bfa')},
#  {'Street': 'Piso en calle La Palma',
#   'District': 'Centro',
#   'Property_Type': 'Piso',
#   'Price': 850,
#   'm2': 50,
#   'Rooms': 1,
#   'location': {'type': 'Point', 'coordinates': [-3.7049167, 40.42642]},
#   '_id': ObjectId('5df7bac1ce267b38a9ae4bfb')},
#  {'Street': 'Apartamento en calle de Claudio Coello',
#   'District': 'Salamanca',
#   'Property_Type': 'Apartamento',
#   'Price': 3500,
#   'm2': 287,
#   'Rooms': 4,
#   'location': {'type': 'Point', 'coordinates': [-3.6863961, 40.4279491]},
#   '_id': ObjectId('5df7bac1ce267b38a9ae4bfc')},
#  {'Street': 'Piso en Trafalgar',
#   'District': 'Chamberí',
#   'Property_Type': 'Piso',
#   'Price': 950,
#   'm2': 53,
#   'Rooms': 2,
#   'location': {'type': 'Point', 'coordinates': [-3.7025439, 40.4299832]},
#   '_id': ObjectId('5df7bac1ce267b38a9ae4bfd')},
#  {'Street': 'Piso en calle de Azcona',
#   'District': 'Salamanca',
#   'Property_Type': 'Piso',
#   'Price': 1500,
#   'm2': 72,
#   'Rooms': 3,
#   'location': {'type': 'Point', 'coordinates': [-3.671107, 40.430508]},
#   '_id': ObjectId('5df7bac1ce267b38a9ae4bfe')},
#  {'Street': 'Piso en calle calle de Vallehermoso',
#   'District': 'Chamberí',
#   'Property_Type': 'Piso',
#   'Price': 1900,
#   'm2': 180,
#   'Rooms': 2,
#   'location': {'type': 'Point', 'coordinates': [-3.7084783, 40.4379486]},
#   '_id': ObjectId('5df7bac1ce267b38a9ae4bff')},
#  {'Street': 'Piso en calle Rodas',
#   'District': 'Centro',
#   'Property_Type': 'Piso',
#   'Price': 850,
#   'm2': 38,
#   'Rooms': 2,
#   'location': {'type': 'Point', 'coordinates': [-3.7057636, 40.408348]},
#   '_id': ObjectId('5df7bac1ce267b38a9ae4c00')},
#  {'Street': 'Piso en calle Fernandez de La Hoz',
#   'District': 'Chamberí',
#   'Property_Type': 'Piso',
#   'Price': 1800,
#   'm2': 70,
#   'Rooms': 1,
#   'location': {'type': 'Point',
#    'coordinates': [-3.6948452, 40.43596429999999]},
#   '_id': ObjectId('5df7bac1ce267b38a9ae4c01')},
#  {'Street': 'Piso en Paseo Imperial',
#   'District': 'Centro',
#   'Property_Type': 'Piso',
#   'Price': 1300,
#   'm2': 50,
#   'Rooms': 2,
#   'location': {'type': 'Point', 'coordinates': [-3.7166143, 40.4066537]},
#   '_id': ObjectId('5df7bac1ce267b38a9ae4c02')},
#  {'Street': 'Apartamento en calle de Sta Engracia',
#   'District': 'Chamberí',
#   'Property_Type': 'Apartamento',
#   'Price': 950,
#   'm2': 61,
#   'Rooms': 1,
#   'location': {'type': 'Point', 'coordinates': [-3.7014559, 40.441724]},
#   '_id': ObjectId('5df7bac1ce267b38a9ae4c03')},
#  {'Street': 'Piso en calle Ángel Muñoz',
#   'District': 'Chamartín',
#   'Property_Type': 'Piso',
#   'Price': 4000,
#   'm2': 404,
#   'Rooms': 5,
#   'location': {'type': 'Point', 'coordinates': [-3.6573617, 40.4540649]},
# ...
#   'District': 'Centro',
#   'Property_Type': 'Piso',
#   'Price': 1400,
#   'm2': 70,
#   'Rooms': 3,
#   'location': {'type': 'Point',
#    'coordinates': [-3.706716299999999, 40.4091878]},
#   '_id': ObjectId('5df7bac1ce267b38a9ae4efd')},
#  {'Street': 'Piso en Avenida de La Osa Mayor',
#   'District': 'Moncloa-Aravaca',
#   'Property_Type': 'Piso',
#   'Price': 2950,
#   'm2': 220,
#   'Rooms': 5,
#   'location': {'type': 'Point',
#    'coordinates': [-3.780101999999999, 40.459321]},
#   '_id': ObjectId('5df7bac1ce267b38a9ae4efe')},
#  {'Street': 'Casa adosada en Hortaleza - Piovera',
#   'District': 'Hortaleza',
#   'Property_Type': 'Casa',
#   'Price': 4500,
#   'm2': 564,
#   'Rooms': 7,
#   'location': {'type': 'Point',
#    'coordinates': [-3.6432882, 40.45043310000001]},
#   '_id': ObjectId('5df7bac1ce267b38a9ae4eff')},
#  {'Street': 'Piso en calle Montalbán',
#   'District': 'Retiro',
#   'Property_Type': 'Piso',
#   'Price': 4200,
#   'm2': 140,
#   'Rooms': 3,
#   'location': {'type': 'Point', 'coordinates': [-3.6906991, 40.4179253]},
#   '_id': ObjectId('5df7bac1ce267b38a9ae4f00')},
#  {'Street': 'Apartamento en calle de Vallehermoso, nº 104',
#   'District': 'Chamberí',
#   'Property_Type': 'Apartamento',
#   'Price': 1000,
#   'm2': 45,
#   'Rooms': 1,
#   'location': {'type': 'Point', 'coordinates': [-3.7091414, 40.4303238]},
#   '_id': ObjectId('5df7bac1ce267b38a9ae4f01')},
#  {'Street': 'Piso en Almenara',
#   'District': 'Tetuán',
#   'Property_Type': 'Piso',
#   'Price': 1590,
#   'm2': 75,
#   'Rooms': 2,
#   'location': {'type': 'Point', 'coordinates': [-0.2232937, 39.753449]},
#   '_id': ObjectId('5df7bac1ce267b38a9ae4f02')},
#  {'Street': 'Piso en calle Diego de León',
#   'District': 'Salamanca',
#   'Property_Type': 'Piso',
#   'Price': 2500,
#   'm2': 120,
#   'Rooms': 2,
#   'location': {'type': 'Point', 'coordinates': [-3.6830351, 40.4347815]},
#   '_id': ObjectId('5df7bac1ce267b38a9ae4f03')},
#  {'Street': 'Apartamento en calle de Zurbano',
#   'District': 'Chamberí',
#   'Property_Type': 'Apartamento',
#   'Price': 1700,
#   'm2': 74,
#   'Rooms': 1,
#   'location': {'type': 'Point', 'coordinates': [-3.6933088, 40.430145]},
#   '_id': ObjectId('5df7bac1ce267b38a9ae4f04')},
#  {'Street': 'Dúplex en calle Damaso Alonso',
#   'District': 'Hortaleza',
#   'Property_Type': 'Dúplex',
#   'Price': 2600,
#   'm2': 180,
#   'Rooms': 3,
#   'location': {'type': 'Point', 'coordinates': [-3.3753636, 40.4958053]},
#   '_id': ObjectId('5df7bac1ce267b38a9ae4f05')},
#  {'Street': 'Piso en calle Zurbano',
#   'District': 'Chamberí',
#   'Property_Type': 'Piso',
#   'Price': 1200,
#   'm2': 30,
#   'Rooms': 1,
#   'location': {'type': 'Point', 'coordinates': [-3.6934569, 40.4341292]},
#   '_id': ObjectId('5df7bac1ce267b38a9ae4f06')},
#  {'Street': 'Ático en calle Fortuny',
#   'District': 'Chamberí',
#   'Property_Type': 'Ático',
#   'Price': 4000,
#   'm2': 170,
#   'Rooms': 4,
#   'location': {'type': 'Point', 'coordinates': [-3.6971889, 40.4193576]},
#   '_id': ObjectId('5df7bac1ce267b38a9ae4f07')},
#  {'Street': 'Piso en Valdebebas',
#   'District': 'Tetuán',
#   'Property_Type': 'Piso',
#   'Price': 1150,
#   'm2': 91,
#   'Rooms': 2,
#   'location': {'type': 'Point', 'coordinates': [-3.6163346, 40.482641]},
#   '_id': ObjectId('5df7bac1ce267b38a9ae4f08')},
#  {'Street': "Apartamento en calle de O'donnell",
#   'District': 'Salamanca',
#   'Property_Type': 'Apartamento',
#   'Price': 2300,
#   'm2': 150,
#   'Rooms': 4,
#   'location': {'type': 'Point', 'coordinates': [-3.6796572, 40.4232011]},
#   '_id': ObjectId('5df7bac1ce267b38a9ae4f09')},
#  {'Street': 'Piso en calle calle de Juan Bravo',
#   'District': 'Salamanca',
#   'Property_Type': 'Piso',
#   'Price': 1400,
#   'm2': 54,
#   'Rooms': 2,
#   'location': {'type': 'Point', 'coordinates': [-3.6742581, 40.4322108]},
#   '_id': ObjectId('5df7bac1ce267b38a9ae4f0a')},
#  {'Street': 'Apartamento en Avenida de Valladolid',
#   'District': 'Moncloa-Aravaca',
#   'Property_Type': 'Apartamento',
#   'Price': 2200,
#   'm2': 182,
#   'Rooms': 4,
#   'location': {'type': 'Point', 'coordinates': [-3.7177947, 40.4211087]},
#   '_id': ObjectId('5df7bac1ce267b38a9ae4f0b')},
#  {'Street': 'Casa adosada en Hortaleza',
#   'District': 'Hortaleza',
#   'Property_Type': 'Casa',
#   'Price': 2600,
#   'm2': 350,
#   'Rooms': 6,
#   'location': {'type': 'Point', 'coordinates': [-3.38195, 40.28186]},
#   '_id': ObjectId('5df7bac1ce267b38a9ae4f0c')},
#  {'Street': 'Piso en calle calle de Rafael Calvo',
#   'District': 'Chamberí',
#   'Property_Type': 'Piso',
#   'Price': 2600,
#   'm2': 120,
#   'Rooms': 2,
#   'location': {'type': 'Point', 'coordinates': [-3.6923273, 40.4342002]},
#   '_id': ObjectId('5df7bac1ce267b38a9ae4f0d')},
#  {'Street': 'Piso en Avenida del General Perón, Madrid, nº 32',
#   'District': 'Tetuán',
#   'Property_Type': 'Piso',
#   'Price': 1450,
#   'm2': 80,
#   'Rooms': 2,
#   'location': {'type': 'Point',
#    'coordinates': [-3.694298799999999, 40.4519151]},
#   '_id': ObjectId('5df7bac1ce267b38a9ae4f0e')},
#  {'Street': 'Ático en calle de Valenzuela',
#   'District': 'Retiro',
#   'Property_Type': 'Ático',
#   'Price': 3900,
#   'm2': 255,
#   'Rooms': 5,
#   'location': {'type': 'Point', 'coordinates': [-3.6971889, 40.4193576]},
#   '_id': ObjectId('5df7bac1ce267b38a9ae4f0f')},
#  {'Street': 'Piso en Lista',
#   'District': 'Salamanca',
#   'Property_Type': 'Piso',
#   'Price': 970,
#   'm2': 40,
#   'Rooms': 1,
#   'location': {'type': 'Point', 'coordinates': [-3.671107, 40.430508]},
#   '_id': ObjectId('5df7bac1ce267b38a9ae4f10')},
#  {'Street': 'Piso en Palomas',
#   'District': 'Hortaleza',
#   'Property_Type': 'Piso',
#   'Price': 800,
#   'm2': 70,
#   'Rooms': 2,
#   'location': {'type': 'Point', 'coordinates': [-3.6198863, 40.4526594]},
#   '_id': ObjectId('5df7bac1ce267b38a9ae4f11')},
#  {'Street': 'Piso en calle Moreto',
#   'District': 'Retiro',
#   'Property_Type': 'Piso',
#   'Price': 3900,
#   'm2': 250,
#   'Rooms': 5,
#   'location': {'type': 'Point', 'coordinates': [-3.6902558, 40.4142478]},
#   '_id': ObjectId('5df7bac1ce267b38a9ae4f12')},
#  {'Street': 'Apartamento en calle Magallanes',
#   'District': 'Chamberí',
#   'Property_Type': 'Apartamento',
#   'Price': 1700,
#   'm2': 110,
#   'Rooms': 2,
#   'location': {'type': 'Point', 'coordinates': [-3.7090905, 40.4282257]},
#   '_id': ObjectId('5df7bac1ce267b38a9ae4f13')},
#  {'Street': 'Piso en calle calle de Jesús',
#   'District': 'Centro',
#   'Property_Type': 'Piso',
#   'Price': 1550,
#   'm2': 71,
#   'Rooms': 2,
#   'location': {'type': 'Point', 'coordinates': [-3.6962952, 40.4110637]},
#   '_id': ObjectId('5df7bac1ce267b38a9ae4f14')},
#  {'Street': 'Piso en Salamanca - Lista',
#   'District': 'Salamanca',
#   'Property_Type': 'Piso',
#   'Price': 4900,
#   'm2': 169,
#   'Rooms': 4,
#   'location': {'type': 'Point', 'coordinates': [-3.6733793, 40.4296398]},
#   '_id': ObjectId('5df7bac1ce267b38a9ae4f15')},
#  {'Street': 'Ático en calle San Julio, nº 3',
#   'District': 'Chamartín',
#   'Property_Type': 'Ático',
#   'Price': 1425,
#   'm2': 120,
#   'Rooms': 1,
#   'location': {'type': 'Point',
#    'coordinates': [-3.680190899999999, 40.4417143]},
#   '_id': ObjectId('5df7bac1ce267b38a9ae4f16')},
#  {'Street': 'Piso en Centro - Universidad - Malasaña',
#   'District': 'Centro',
#   'Property_Type': 'Piso',
#   'Price': 1900,
#   'm2': 130,
#   'Rooms': 1,
#   'location': {'type': 'Point', 'coordinates': [-3.706918, 40.424238]},
#   '_id': ObjectId('5df7bac1ce267b38a9ae4f17')},
#  {'Street': 'Dúplex en Avenida de Valdemarín',
#   'District': 'Moncloa-Aravaca',
#   'Property_Type': 'Dúplex',
#   'Price': 2650,
#   'm2': 200,
#   'Rooms': 4,
#   'location': {'type': 'Point', 'coordinates': [-3.7848803, 40.4689121]},
#   '_id': ObjectId('5df7bac1ce267b38a9ae4f18')},
#  {'Street': 'Piso en Virgen del Cortijo-Manoteras',
#   'District': 'Hortaleza',
#   'Property_Type': 'Piso',
#   'Price': 1600,
#   'm2': 97,
#   'Rooms': 2,
#   'location': {'type': 'Point', 'coordinates': [-3.6610546, 40.4874603]},
#   '_id': ObjectId('5df7bac1ce267b38a9ae4f19')},
#  {'Street': 'Piso en Argüelles',
#   'District': 'Moncloa-Aravaca',
#   'Property_Type': 'Piso',
#   'Price': 1090,
#   'm2': 63,
#   'Rooms': 1,
#   'location': {'type': 'Point', 'coordinates': [-3.721413, 40.4294136]},
#   '_id': ObjectId('5df7bac1ce267b38a9ae4f1a')},
#  {'Street': 'Piso en Salamanca - Castellana',
#   'District': 'Salamanca',
#   'Property_Type': 'Piso',
#   'Price': 2600,
#   'm2': 150,
#   'Rooms': 4,
#   'location': {'type': 'Point', 'coordinates': [-3.6865905, 40.4308394]},
#   '_id': ObjectId('5df7bac1ce267b38a9ae4f1b')},
#  {'Street': 'Piso en Recoletos',
#   'District': 'Salamanca',
#   'Property_Type': 'Piso',
#   'Price': 2500,
#   'm2': 127,
#   'Rooms': 2,
#   'location': {'type': 'Point', 'coordinates': [-3.6866377, 40.4238593]},
#   '_id': ObjectId('5df7bac1ce267b38a9ae4f1c')},
#  {'Street': 'Apartamento en Centro',
#   'District': 'Centro',
#   'Property_Type': 'Apartamento',
#   'Price': 1450,
#   'm2': 90,
#   'Rooms': 1,
#   'location': {'type': 'Point', 'coordinates': [-3.696856, 40.424815]},
#   '_id': ObjectId('5df7bac1ce267b38a9ae4f1d')},
#  {'Street': 'Apartamento en calle de Serrano',
#   'District': 'Salamanca',
#   'Property_Type': 'Apartamento',
#   'Price': 2700,
#   'm2': 110,
#   'Rooms': 2,
#   'location': {'type': 'Point', 'coordinates': [-3.6900327, 40.4227751]},
#   '_id': ObjectId('5df7bac1ce267b38a9ae4f1e')},
#  {'Street': 'Apartamento en calle de José Abascal',
#   'District': 'Chamberí',
#   'Property_Type': 'Apartamento',
#   'Price': 1300,
#   'm2': 50,
#   'Rooms': 2,
#   'location': {'type': 'Point',
#    'coordinates': [-3.693584199999999, 40.4379469]},
#   '_id': ObjectId('5df7bac1ce267b38a9ae4f1f')},
#  {'Street': 'Apartamento en Castellana',
#   'District': 'Salamanca',
#   'Property_Type': 'Apartamento',
#   'Price': 850,
#   'm2': 38,
#   'Rooms': 1,
#   'location': {'type': 'Point', 'coordinates': [-3.6895319, 40.4370851]},
#   '_id': ObjectId('5df7bac1ce267b38a9ae4f20')},
#  {'Street': 'Apartamento en calle Herreros de Tejada',
#   'District': 'Chamartín',
#   'Property_Type': 'Apartamento',
#   'Price': 3300,
#   'm2': 157,
#   'Rooms': 3,
#   'location': {'type': 'Point', 'coordinates': [-3.680190899999999, 40.45888]},
#   '_id': ObjectId('5df7bac1ce267b38a9ae4f21')},
#  {'Street': 'Piso en Nueva España',
#   'District': 'Chamartín',
#   'Property_Type': 'Piso',
#   'Price': 4000,
#   'm2': 309,
#   'Rooms': 4,
#   'location': {'type': 'Point', 'coordinates': [-3.67758, 40.45892]},
#   '_id': ObjectId('5df7bac1ce267b38a9ae4f22')},
#  {'Street': 'Piso en calle Avenida de Alfonso XIII',
#   'District': 'Chamartín',
#   'Property_Type': 'Piso',
#   'Price': 2750,
#   'm2': 226,
#   'Rooms': 3,
#   'location': {'type': 'Point',
#    'coordinates': [-3.6673399, 40.45101349999999]},
#   '_id': ObjectId('5df7bac1ce267b38a9ae4f23')},
#  {'Street': 'Piso en calle del Doctor Castelo, Madrid, nº 24',
#   'District': 'Retiro',
#   'Property_Type': 'Piso',
#   'Price': 1600,
#   'm2': 76,
#   'Rooms': 2,
#   'location': {'type': 'Point', 'coordinates': [-3.6763414, 40.420296]},
#   '_id': ObjectId('5df7bac1ce267b38a9ae4f24')},
#  {'Street': 'Apartamento en calle Clara del Rey, Madrid',
#   'District': 'Chamartín',
#   'Property_Type': 'Apartamento',
#   'Price': 1150,
#   'm2': 110,
#   'Rooms': 3,
#   'location': {'type': 'Point', 'coordinates': [-3.6735424, 40.4395296]},
#   '_id': ObjectId('5df7bac1ce267b38a9ae4f25')},
#  {'Street': 'Apartamento en Centro',
#   'District': 'Centro',
#   'Property_Type': 'Apartamento',
#   'Price': 1500,
#   'm2': 85,
#   'Rooms': 1,
#   'location': {'type': 'Point', 'coordinates': [-3.696856, 40.424815]},
#   '_id': ObjectId('5df7bac1ce267b38a9ae4f26')},
#  {'Street': 'Piso en calle del Conde de Romanones, Madrid, nº 5',
#   'District': 'Centro',
#   'Property_Type': 'Piso',
#   'Price': 2900,
#   'm2': 140,
#   'Rooms': 5,
#   'location': {'type': 'Point', 'coordinates': [-3.7046488, 40.4135099]},
#   '_id': ObjectId('5df7bac1ce267b38a9ae4f27')},
#  {'Street': 'Ático en Salamanca',
#   'District': 'Salamanca',
#   'Property_Type': 'Ático',
#   'Price': 3200,
#   'm2': 110,
#   'Rooms': 2,
#   'location': {'type': 'Point',
#    'coordinates': [-5.665013999999999, 40.964849]},
#   '_id': ObjectId('5df7bac1ce267b38a9ae4f28')},
#  {'Street': 'Apartamento en Chamberí',
#   'District': 'Chamberí',
#   'Property_Type': 'Apartamento',
#   'Price': 2500,
#   'm2': 100,
#   'Rooms': 2,
#   'location': {'type': 'Point', 'coordinates': [-3.7091414, 40.4303238]},
#   '_id': ObjectId('5df7bac1ce267b38a9ae4f29')},
#  {'Street': 'Piso en Chamartín - El Viso',
#   'District': 'Chamartín',
#   'Property_Type': 'Piso',
#   'Price': 4500,
#   'm2': 399,
#   'Rooms': 6,
#   'location': {'type': 'Point', 'coordinates': [-3.6866813, 40.4490213]},
#   '_id': ObjectId('5df7bac1ce267b38a9ae4f2a')},
#  {'Street': 'Piso en calle de Narváez',
#   'District': 'Retiro',
#   'Property_Type': 'Piso',
#   'Price': 3600,
#   'm2': 150,
#   'Rooms': 4,
#   'location': {'type': 'Point', 'coordinates': [-3.6762424, 40.4208912]},
#   '_id': ObjectId('5df7bac1ce267b38a9ae4f2b')},
#  {'Street': 'Piso en Chamberí - Ríos Rosas - Nuevos Ministerios',
#   'District': 'Chamberí',
#   'Property_Type': 'Piso',
#   'Price': 3900,
#   'm2': 338,
#   'Rooms': 4,
#   'location': {'type': 'Point', 'coordinates': [-3.6973587, 40.4419465]},
#   '_id': ObjectId('5df7bac1ce267b38a9ae4f2c')},
#  {'Street': 'Apartamento en calle Desengaño',
#   'District': 'Centro',
#   'Property_Type': 'Apartamento',
#   'Price': 1490,
#   'm2': 55,
#   'Rooms': 1,
#   'location': {'type': 'Point', 'coordinates': [-3.7022632, 40.420784]},
#   '_id': ObjectId('5df7bac1ce267b38a9ae4f2d')},
#  {'Street': 'Piso en calle de Juan Ramón Jiménez',
#   'District': 'Chamartín',
#   'Property_Type': 'Piso',
#   'Price': 1900,
#   'm2': 85,
#   'Rooms': 1,
#   'location': {'type': 'Point', 'coordinates': [-3.8330498, 40.3380781]},
#   '_id': ObjectId('5df7bac1ce267b38a9ae4f2e')},
#  {'Street': 'Ático en Salamanca',
#   'District': 'Salamanca',
#   'Property_Type': 'Ático',
#   'Price': 1950,
#   'm2': 130,
#   'Rooms': 4,
#   'location': {'type': 'Point',
#    'coordinates': [-5.665013999999999, 40.964849]},
#   '_id': ObjectId('5df7bac1ce267b38a9ae4f2f')},
#  {'Street': 'Piso en calle General Peron',
#   'District': 'Tetuán',
#   'Property_Type': 'Piso',
#   'Price': 1500,
#   'm2': 100,
#   'Rooms': 2,
#   'location': {'type': 'Point', 'coordinates': [-3.6993734, 40.4533446]},
#   '_id': ObjectId('5df7bac1ce267b38a9ae4f30')},
#  {'Street': 'Piso en Bellas Vistas',
#   'District': 'Tetuán',
#   'Property_Type': 'Piso',
#   'Price': 1500,
#   'm2': 124,
#   'Rooms': 3,
#   'location': {'type': 'Point', 'coordinates': [-3.7089197, 40.4526738]},
#   '_id': ObjectId('5df7bac1ce267b38a9ae4f31')},
#  {'Street': 'Apartamento en Salamanca',
#   'District': 'Salamanca',
#   'Property_Type': 'Apartamento',
#   'Price': 2000,
#   'm2': 122,
#   'Rooms': 3,
#   'location': {'type': 'Point',
#    'coordinates': [-5.663330999999999, 40.963884]},
#   '_id': ObjectId('5df7bac1ce267b38a9ae4f32')},
#  {'Street': 'Dúplex en calle Peñalara',
#   'District': 'Moncloa-Aravaca',
#   'Property_Type': 'Dúplex',
#   'Price': 1800,
#   'm2': 144,
#   'Rooms': 4,
#   'location': {'type': 'Point',
#    'coordinates': [-3.801401899999999, 40.4587767]},
#   '_id': ObjectId('5df7bac1ce267b38a9ae4f33')},
#  {'Street': 'Apartamento en Centro',
#   'District': 'Centro',
#   'Property_Type': 'Apartamento',
#   'Price': 1500,
#   'm2': 105,
#   'Rooms': 2,
#   'location': {'type': 'Point', 'coordinates': [-3.696856, 40.424815]},
#   '_id': ObjectId('5df7bac1ce267b38a9ae4f34')},
#  {'Street': 'Piso en Embajadores-Lavapiés',
#   'District': 'Centro',
#   'Property_Type': 'Piso',
#   'Price': 1100,
#   'm2': 60,
#   'Rooms': 1,
#   'location': {'type': 'Point', 'coordinates': [-3.7015352, 40.4088507]},
#   '_id': ObjectId('5df7bac1ce267b38a9ae4f35')},
#  {'Street': 'Ático en calle calle del Barco',
#   'District': 'Centro',
#   'Property_Type': 'Ático',
#   'Price': 1800,
#   'm2': 70,
#   'Rooms': 1,
#   'location': {'type': 'Point', 'coordinates': [-3.6971889, 40.4193576]},
#   '_id': ObjectId('5df7bac1ce267b38a9ae4f36')},
#  {'Street': 'Piso en calle calle de Alcantara',
#   'District': 'Salamanca',
#   'Property_Type': 'Piso',
#   'Price': 780,
#   'm2': 50,
#   'Rooms': 1,
#   'location': {'type': 'Point', 'coordinates': [-3.6862323, 40.4380946]},
#   '_id': ObjectId('5df7bac1ce267b38a9ae4f37')},
#  {'Street': 'Piso en calle Barrilero',
#   'District': 'Retiro',
#   'Property_Type': 'Piso',
#   'Price': 1700,
#   'm2': 70,
#   'Rooms': 2,
#   'location': {'type': 'Point', 'coordinates': [-3.6741361, 40.4007975]},
#   '_id': ObjectId('5df7bac1ce267b38a9ae4f38')},
#  ...]
