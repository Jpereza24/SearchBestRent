# %%
import pandas as pd
import requests as rq
from dotenv import load_dotenv
import base64
import os
import urllib
import json
load_dotenv()
from src import API as api

# %%
country = 'es' #values: es, it, pt
locale = 'es' #values: es, it, pt, en, ca
language = 'es' #
max_items = '50'
operation = 'rent' 
property_type = 'homes'
order = 'priceDown' 
center = '40.24594,-3.42922' 
distance = '60000'
sort = 'desc'

df_tot = pd.DataFrame()
limit = 20

for i in range(1,limit):
    url = ('https://api.idealista.com/3.5/'+country+'/search?operation='+operation+#"&locale="+locale+
           '&maxItems='+max_items+
           '&order='+order+
           '&center='+center+
           '&distance='+distance+
           '&propertyType='+property_type+
           '&sort='+sort+ 
           '&numPage=%s'+
           '&language='+language) %(i)  
    a = api.search_api(api.get_oauth_token(), url)
    df = pd.DataFrame.from_dict(a['elementList'])
    df_tot = pd.concat([df_tot,df])

df_tot = df_tot.reset_index()
# Out:
# /home/joaquin/.local/lib/python3.7/site-packages/ipykernel_launcher.py:27: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.

# %%
df_tot['district'].value_counts()
# Out:
# Centro          151
# Salamanca       118
# Chamartín        81
# Chamberí         73
# Moncloa          51
#                ...
# Suroeste          1
# El Puerto         1
# Zona Europa       1
# Parla Este        1
# Zarzaquemada      1
# Name: district, Length: 95, dtype: int64

# %%
df_tot.isna().sum()
# Out:
# index                  0
# address                0
# bathrooms              0
# detailedType           0
# distance               0
# district              46
# exterior               0
# externalReference    200
# floor                153
# latitude               0
# longitude              0
# municipality           0
# neighborhood         206
# operation              0
# parkingSpace         594
# price                  0
# priceByArea            0
# propertyCode           0
# propertyType           0
# rooms                  0
# showAddress            0
# size                   0
# status                76
# suggestedTexts         0
# dtype: int64

# %%
col = ['status', 'operation', 'showAddress']
df_tot.drop(col, axis=1, inplace=True)

# %%
df_tot.shape
# Out:
# (950, 21)

# %%
df_tot
# Out:
#      index                         address  bathrooms  \
# 0        0   Calle de Carretas, Madrid, 25          1
# 1        1   Calle de Carretas, Madrid, 25          1
# 2        2   Calle de Carretas, Madrid, 25          1
# 3        3                   Calle Iriarte          1
# 4        4                     La Moraleja          5
# ..     ...                             ...        ...
# 945     45       Avenida de Machupichu s/n          1
# 946     46  Calle Virgen de la Paz, Madrid          1
# 947     47                Calle Navaluenga          1
# 948     48  Calle de Antonio López, Madrid          1
# 949     49        barrio Cuzco-Castillejos          1
#
#                                           detailedType distance  \
# 0        {'typology': 'flat', 'subTypology': 'studio'}    29898
# 1     {'typology': 'flat', 'subTypology': 'penthouse'}    29898
# 2        {'typology': 'flat', 'subTypology': 'studio'}    29898
# 3                                 {'typology': 'flat'}    29597
# 4    {'typology': 'chalet', 'subTypology': 'indepen...    34325
# ..                                                 ...      ...
# 945                               {'typology': 'flat'}    29246
# 946                               {'typology': 'flat'}    28300
# 947                               {'typology': 'flat'}    44442
# 948                               {'typology': 'flat'}    29570
# 949                               {'typology': 'flat'}    32608
#
#                        district  exterior     externalReference floor  \
# 0                        Centro      True   Sol 4A Stu Int Atic     4
# 1                        Centro     False      Sol 3C Int Attic     3
# 2                        Centro     False       Carretas Bajo B    bj
# 3                     Salamanca     False  ca31875ef7d0d581c9eb     1
# 4                   La Moraleja     False                MOAI87   NaN
# ..                          ...       ...                   ...   ...
# 945                   Hortaleza      True                   NaN     2
# 946               Ciudad Lineal      True                  2020     7
# 947  Zona Carretera del Plantío      True                   NaN     2
# 948                 Carabanchel     False            3455-00390     3
# 949                      Tetuán      True             AM1910067     5
#
#       latitude  ...  municipality         neighborhood  \
# 0    40.415349  ...        Madrid                  Sol
# 1    40.415349  ...        Madrid                  Sol
# 2    40.415349  ...        Madrid                  Sol
# 3    40.436956  ...        Madrid           Guindalera
# 4    40.522564  ...   La Moraleja                  NaN
# ..         ...  ...           ...                  ...
# 945  40.460341  ...        Madrid  Conde Orgaz-Piovera
# 946  40.430347  ...        Madrid           Concepción
# 947  40.478473  ...   Majadahonda                  NaN
# 948  40.398563  ...        Madrid             Comillas
# 949  40.459016  ...        Madrid    Cuzco-Castillejos
#
#                                           parkingSpace    price  priceByArea  \
# 0                                                  NaN    946.0         32.0
# 1                                                  NaN    946.0         32.0
# 2                                                  NaN    946.0         21.0
# 3    {'hasParkingSpace': True, 'isParkingSpaceInclu...   1300.0         19.0
# 4    {'hasParkingSpace': True, 'isParkingSpaceInclu...  10000.0         12.0
# ..                                                 ...      ...          ...
# 945  {'hasParkingSpace': True, 'isParkingSpaceInclu...    950.0         22.0
# 946  {'hasParkingSpace': True, 'isParkingSpaceInclu...    900.0         15.0
# 947  {'hasParkingSpace': True, 'isParkingSpaceInclu...    940.0         13.0
# 948                                                NaN    900.0         20.0
# 949                                                NaN   1800.0         24.0
#
#      propertyCode propertyType rooms   size  \
# 0        84203646       studio     0   30.0
# 1        84590828    penthouse     1   30.0
# 2        84227990       studio     0   45.0
# 3        87191834         flat     1   70.0
# 4        84907032       chalet     5  850.0
# ..            ...          ...   ...    ...
# 945      87408912         flat     1   44.0
# 946      82134337         flat     1   62.0
# 947      87707854         flat     1   72.0
# 948      83778654         flat     2   45.0
# 949      87373263         flat     1   76.0
#
#                                         suggestedTexts
# 0    {'subtitle': 'Sol, Madrid', 'title': 'Estudio ...
# 1    {'subtitle': 'Sol, Madrid', 'title': 'Ático en...
# 2    {'subtitle': 'Sol, Madrid', 'title': 'Estudio ...
# 3    {'subtitle': 'Guindalera, Madrid', 'title': 'P...
# 4    {'subtitle': 'La Moraleja, La Moraleja', 'titl...
# ..                                                 ...
# 945  {'subtitle': 'Conde Orgaz-Piovera, Madrid', 't...
# 946  {'subtitle': 'Concepción, Madrid', 'title': 'P...
# 947  {'subtitle': 'Zona Carretera del Plantío, Maja...
# 948  {'subtitle': 'Comillas, Madrid', 'title': 'Pis...
# 949  {'subtitle': 'Cuzco-Castillejos, Madrid', 'tit...
#
# [950 rows x 21 columns]

# %%
df1 = df_tot.groupby('district', as_index=False).agg({'price':'mean'})

# %%
df1
# Out:
#                                district        price
# 0                     Alcobendas Centro   850.000000
# 1         Altos del Olivar - El Caracol   750.000000
# 2                            Arganzuela  1225.347826
# 3                     Arroyo de la Vega  2050.000000
# 4                               Barajas  1006.600000
# ..                                  ...          ...
# 90           Zona Carretera del Plantío   940.000000
# 91                          Zona Europa  1300.000000
# 92                  Zona Monte el Pilar  1866.666667
# 93  Zona Prado de Somosaguas - La Finca  2933.333333
# 94                           Zona norte  1593.750000
#
# [95 rows x 2 columns]
